# %%
import random
import buildNetwork
import basicRunDORA
import pdb
import numpy as np
import seaborn as sns
NUM_ANALOGS = 4
N_COMPONENTS = 10
PER_ANALOG = 5

# %%
parameters = {'asDORA': True, 'gamma': 0.3,
              'delta': 0.05, 'eta': 0.9,
              'HebbBias': 0.5,
              'bias_retrieval_analogs': False, 'use_relative_act': False, # Changeeeeddd!!!!!!!!
              #'run_order': ['cdr', 'selectTokens', 'r', 'wp', 'm', 'p', 's', 'f', 'c'],
              'run_order': ['cdr', 'selectTokens', 'r', 'm','c'],
              'run_cyles': 100, 'write_on_iteration': 100, 'firingOrderRule': 'in_order',
              'dim_list':[],
              'strategic_mapping': True, 'ignore_object_semantics': False,
              'ignore_memory_semantics': True, 'mag_decimal_precision': 0,
              'exemplar_memory': False, 'recent_analog_bias': True,
              'lateral_input_level': 1, 'screen_width': 1200, 'screen_height': 700,
              'doGUI': False, 'testing': True, 'GUI_update_rate': 50, 'starting_iteration': 0,
              'tokenize': False, 'ho_sem_act_flow': 0, 'remove_uncompressed': False, 'remove_compressed': False,
              'num_choose':10,'one_to_one':True,'max_norm':True, 'filename':'karthikeya/test_sim_custom-cbow-7-empty_pred.py',
             'len_regularisation':1, 'count_by_RBs':False, 'parent_bias':0.1, 'order_activation_bias':0.5}

# %%
def init_network(parameters):
    reload(buildNetwork)
    reload(basicRunDORA)
    fileName = parameters['filename']
    f = open(fileName, 'r')
    simType = ''
    d = {'simType': simType}
    f.seek(0)
    exec (f.readline())
    if simType == 'sym_file':
        symstring = ''
        for line in f:
            symstring += line
        exec(symstring)
    # initialise memory
    memory = buildNetwork.initializeMemorySet()
    # interpret sym file
    mysym = buildNetwork.interpretSymfile(symProps)
    # build the network
    memory = basicRunDORA.dataTypes.memorySet()
    memory = buildNetwork.buildTheNetwork(mysym[0], memory)
    network = basicRunDORA.runDORA(memory, parameters)
    memory = basicRunDORA.update_memory_with_levels(memory)
    # run cycles
    # initialise mapping adjacency matrix:
    mapping_adj = np.zeros((len(network.memory.Ps), len(network.memory.Ps)))
    return [network, memory, mapping_adj]

# %%
def vis_mappings(mapping_mat, prop_names):
    sns_heatmap = sns.heatmap(mapping_mat, linewidth=0.5,xticklabels=prop_names, yticklabels=prop_names)
    fig = sns_heatmap.get_figure()
    return

# %%
def mapping_error(mapping_mat):
    # assuming an even split - NUM_ANALOGS * PER_ANALOG = number of analogs, number of propositions per analog
    # the mapping matrix is ordered by propositions, therefore every n%PER_ANALOG should be mapped together.
    # the mapping_mat is L1 normalised, and so the target matrix should contain values = 1.0/(NUM_ANALOGS - 1)
    target_mat = np.zeros(mapping_mat.shape)
    per_analog = mapping_mat.shape[0]/NUM_ANALOGS
    for row in range(target_mat.shape[0]):
        target_indices = [(idx*per_analog + row%per_analog) for idx in range(NUM_ANALOGS)] # fill the target mapping indices
        target_indices.pop(target_indices.index(row))
        target_mat[row,target_indices] = 1.0/(NUM_ANALOGS - 1)
    mapping_mat = mapping_mat * (target_mat > 0) # keep only diagonals for comparisons
    error_mat = (mapping_mat - target_mat)**2
    error_val = np.sqrt(np.mean(error_mat))
    return error_val

# %%
def get_metrics(mapping_mat):
    # mapping_mat contains the predicted mappings
    target_mat = np.zeros(mapping_mat.shape)
    per_analog = mapping_mat.shape[0]/NUM_ANALOGS
    for row in range(target_mat.shape[0]):
        target_indices = [(idx*per_analog + row%per_analog) for idx in range(NUM_ANALOGS)] # fill the target mapping indices
        target_indices.pop(target_indices.index(row))
        target_mat[row,target_indices] = 1
    # target_mat contains the true mappings in boolean values
    # Get True Positives (TP)
    true_positives = sum(sum(mapping_mat * target_mat))
    # False Positives (FP) 
    false_positives =  sum(np.sum(mapping_mat * abs(target_mat-1), axis=0))# gives all those non-zero mappings at the wrong place.
    # False Negatives (FN) giving zero mapping when it should actually be non zero
    false_negatives = sum(np.sum(mapping_mat * abs(target_mat-1), axis=1)) 
    precision = true_positives/(true_positives + false_positives)
    recall = true_positives/(true_positives + false_negatives) 
    f_score = (2 * precision * recall) / (precision + recall)
    rmse = mapping_error(mapping_mat)
    return precision, recall, f_score, rmse

# %%
# networ, memory, mapping_adj = init_network()
for cycle in range(parameters['run_cyles']):
    print('\n\n************************* Cycle: ' + str(cycle+1))

    # clear driver and recipient
    network.memory = basicRunDORA.clearDriverSet(network.memory)
    network.memory = basicRunDORA.clearRecipientSet(network.memory)

    # put the randomly chosen proposition in the driver
    proposition = random.sample(network.memory.Ps,k=parameters['num_choose']) # currently three propositions
    if parameters['num_choose'] > 1:
        proposition_num = []
        for p in proposition:
            proposition_num.append(network.memory.Ps.index(p))
    else:
        proposition_num = network.memory.Ps.index(proposition)

    if parameters['num_choose'] > 1:
        for p_num in proposition_num:
            network.memory = basicRunDORA.add_tokens_to_set(network.memory, p_num, 'P', 'driver')
    else:
        network.memory = basicRunDORA.add_tokens_to_set(network.memory, proposition_num, 'P', 'driver')



    # make sure the driver and the recipient are set
    network.memory = basicRunDORA.findDriverRecipient(network.memory)
    network.do_map()

    # display ALL mappings
    #pdb.set_trace()
    for myP in network.memory.driver.Ps:
        for mapping in myP.mappingConnections:
            map_weight = mapping.weight
            if map_weight > 0:
                map_unit = mapping.recipientToken
                if mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)] < 0.1:
                    mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)] = map_weight
                else:
                    mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)] = (map_weight + 
                        mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)])/2.0 # DIRTY SOLUTION FOR NOW
            #print str(network.memory.Ps.index(myP)) + str(' -- ') + str(network.memory.Ps.index(map_unit)) + str(' : ') + str(map_weight)
    # display mappings
    print('\n\nMappings:\n')
    basicRunDORA.DORA_GUI.term_map_display(network.memory, only_Ps=True, only_max=False)

# %%
def print_map_connections(network):
    for myP in network.memory.driver.Ps:
        for mapping in myP.mappingConnections:
            print myP.name, mapping.recipientToken.name, mapping.weight

# %%
network, memory, mapping_adj = init_network(parameters)
precisions, recalls, fscores, rmses = [],[],[],[]
for cycle in range(parameters['run_cyles']):
    print('\n\n************************* Cycle: ' + str(cycle+1))
    #pdb.set_trace()
    # clear driver and recipient
    network.memory = basicRunDORA.clearDriverSet(network.memory)
    network.memory = basicRunDORA.clearRecipientSet(network.memory)
    # choose random analog from memory
    analog = random.choice(network.memory.analogs) # currently only one analog
    # choose random propositions from memory

    # put the analog in the driver
    analog_num = network.memory.analogs.index(analog)
    network.memory = basicRunDORA.add_tokens_to_set(network.memory, analog_num, 'analog', 'driver')
    # retrieve analogs similar to one in the driver from LTM
    network.memory = basicRunDORA.findDriverRecipient(network.memory)
    network.do_retrieval()
    network.memory = basicRunDORA.findDriverRecipient(network.memory)
    
    #print('In driver : ' + network.memory.driver.Ps[0].name[1])
    #if len(network.memory.recipient.Ps) > 0:
    #    print('In recipient : ' + network.memory.recipient.Ps[0].name[1])
    #    if network.memory.recipient.Ps[0].name[1] == '3':
    #        network.do_map()
    #        print('\n\nMappings:\n')
    #        basicRunDORA.DORA_GUI.term_map_display(network.memory, only_Ps=True, only_max=False)

    if len(network.memory.recipient.Ps) > 0: 
        print 'retrieval successful'
        # map the analogs in driver and recipient
        network.do_map()
        # display ALL mappings
        # display mappings
        print('\n\nMappings:\n')
        basicRunDORA.DORA_GUI.term_map_display(network.memory, only_Ps=False, only_max=False)
        # store all mappings : 
        for myP in network.memory.driver.Ps:
            for mapping in myP.mappingConnections:
                map_weight = mapping.weight
                map_unit = mapping.recipientToken
                mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)] = map_weight
    # append rmse to list to keep track of RMSE evolution
    temp_mapping_adj  = mapping_adj
    for ind in range(temp_mapping_adj.shape[0]):
        if sum(temp_mapping_adj[ind,:]) > 0:
            temp_mapping_adj[ind,:] = temp_mapping_adj[ind,:]/sum(temp_mapping_adj[ind,:])    
    prec,rec,fsc,rmse = get_metrics(temp_mapping_adj)
    precisions.append(prec)
    recalls.append(rec)
    fscores.append(fsc)
    rmses.append(rmse)
    
# normalise mappings
for ind in range(mapping_adj.shape[0]):
    if sum(mapping_adj[ind,:]) > 0:
        mapping_adj[ind,:] = mapping_adj[ind,:]/sum(mapping_adj[ind,:])
# Out:
# ************************* Cycle: 1
# retrieval successful
#
#
# Mappings:
#
# ('P: P30 -- NONE -- mapping_weight=', 0.0)
# ('P: P31 -- P23.1 -- mapping_weight=', 0.8335990966560927)
# ('P: P32 -- NONE -- mapping_weight=', 0.0)
# ('P: P33.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P33 -- P23 -- mapping_weight=', 1)
# ('P: P34.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P34 -- NONE -- mapping_weight=', 0.0)
# ('P: P35.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P35.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P35 -- NONE -- mapping_weight=', 0.0)
# ('P: P36.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P36.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P36 -- NONE -- mapping_weight=', 0.0)
# ('P: P37.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P37 -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: angrysnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: hissobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: slitherobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP33.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: juicyrats -- NONE -- mapping_weight=', 0.0)
# ('RB: cunningsnakes -- spoteagles -- mapping_weight=', 0.24997693098928844)
# ('RB: loveP34.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: spottedsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: atdanger -- NONE -- mapping_weight=', 0.0)
# ('RB: slenderP35.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: rattleP35.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: towardstraps -- NONE -- mapping_weight=', 0.0)
# ('RB: quietlyP36.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detrats -- detworms -- mapping_weight=', 0.6164165533818338)
# ('RB: wobbleP36.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: hairyrats -- NONE -- mapping_weight=', 0.0)
# ('RB: fatP37.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: scurryabout -- earlyworms -- mapping_weight=', 0.20013260885729514)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: snakes -- eagles -- mapping_weignt=', 1)
# ('PO: eat -- say -- mapping_weignt=', 0.9736936216623769)
# ('PO: rats -- worms -- mapping_weignt=', 1)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: hiss -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: slither -- early -- mapping_weignt=', 0.941911714149796)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: juicy -- NONE -- mapping_weignt=', 0.0)
# ('PO: cunning -- NONE -- mapping_weignt=', 0.0)
# ('PO: love -- NONE -- mapping_weignt=', 0.0)
# ('PO: spotted -- NONE -- mapping_weignt=', 0.0)
# ('PO: at -- NONE -- mapping_weignt=', 0.0)
# ('PO: danger -- NONE -- mapping_weignt=', 0.0)
# ('PO: slender -- NONE -- mapping_weignt=', 0.0)
# ('PO: rattle -- NONE -- mapping_weignt=', 0.0)
# ('PO: towards -- NONE -- mapping_weignt=', 0.0)
# ('PO: traps -- NONE -- mapping_weignt=', 0.0)
# ('PO: quietly -- NONE -- mapping_weignt=', 0.0)
# ('PO: wobble -- spot -- mapping_weignt=', 1)
# ('PO: hairy -- NONE -- mapping_weignt=', 0.0)
# ('PO: fat -- NONE -- mapping_weignt=', 0.0)
# ('PO: scurry -- NONE -- mapping_weignt=', 0.0)
# ('PO: about -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 2
# retrieval successful
#
#
# Mappings:
#
# ('P: P00 -- NONE -- mapping_weight=', 0.0)
# ('P: P01 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P02 -- NONE -- mapping_weight=', 0.0)
# ('P: P03.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P03 -- NONE -- mapping_weight=', 0.0)
# ('P: P04.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P04 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P05 -- NONE -- mapping_weight=', 0.0)
# ('P: P06.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P06.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P06 -- NONE -- mapping_weight=', 0.0)
# ('P: P07.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P07 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: chasecats -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: barkobj -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: growlobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: bitecats -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP03.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: smallcats -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: biteP04.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: growlP05.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fromwater -- NONE -- mapping_weight=', 0.0)
# ('RB: awayP06.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detkitten -- NONE -- mapping_weight=', 0.0)
# ('RB: stayP06.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fluffycats -- NONE -- mapping_weight=', 0.0)
# ('RB: cuteP07.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: dogs -- lions -- mapping_weignt=', 0.4599710460033329)
# ('PO: chase -- NONE -- mapping_weignt=', 0.0)
# ('PO: cats -- deer -- mapping_weignt=', 0.4185210163642257)
# ('PO: hungry -- glide -- mapping_weignt=', 0.7949619622264374)
# ('PO: bark -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- majestic -- mapping_weignt=', 0.285852263746437)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: small -- NONE -- mapping_weignt=', 0.0)
# ('PO: at -- NONE -- mapping_weignt=', 0.0)
# ('PO: strangers -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: from -- NONE -- mapping_weignt=', 0.0)
# ('PO: water -- NONE -- mapping_weignt=', 0.0)
# ('PO: away -- NONE -- mapping_weignt=', 0.0)
# ('PO: kitten -- NONE -- mapping_weignt=', 0.0)
# ('PO: stay -- NONE -- mapping_weignt=', 0.0)
# ('PO: fluffy -- NONE -- mapping_weignt=', 0.0)
# ('PO: cute -- NONE -- mapping_weignt=', 0.0)
# ('PO: purr -- NONE -- mapping_weignt=', 0.0)
# ('PO: softly -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 3
# retrieval successful
#
#
# Mappings:
#
# ('P: P30 -- NONE -- mapping_weight=', 0.0)
# ('P: P31 -- P23.1 -- mapping_weight=', 0.8335990966560927)
# ('P: P32 -- P12 -- mapping_weight=', 0.5001922431851608)
# ('P: P33.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P33 -- P23 -- mapping_weight=', 1)
# ('P: P34.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P34 -- NONE -- mapping_weight=', 0.0)
# ('P: P35.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P35.2 -- P15.2 -- mapping_weight=', 0.4056569173422296)
# ('P: P35 -- P15 -- mapping_weight=', 1)
# ('P: P36.1 -- P16.1 -- mapping_weight=', 0.8720922244842585)
# ('P: P36.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P36 -- NONE -- mapping_weight=', 0.0)
# ('P: P37.1 -- P15.1 -- mapping_weight=', 0.9899148853795916)
# ('P: P37 -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: angrysnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: hissobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: slitherobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP33.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: juicyrats -- inanger -- mapping_weight=', 0.1174741689685893)
# ('RB: cunningsnakes -- spoteagles -- mapping_weight=', 0.24997693098928844)
# ('RB: loveP34.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: spottedsnakes -- jumpobj -- mapping_weight=', 1)
# ('RB: atdanger -- detdeer -- mapping_weight=', 0.18090629765916455)
# ('RB: slenderP35.1 -- roarP15.2 -- mapping_weight=', 1)
# ('RB: rattleP35.2 -- majesticP15.1 -- mapping_weight=', 1)
# ('RB: towardstraps -- intodarkness -- mapping_weight=', 0.7343467198141006)
# ('RB: quietlyP36.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detrats -- detworms -- mapping_weight=', 0.6164165533818338)
# ('RB: wobbleP36.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: hairyrats -- malelions -- mapping_weight=', 0.8069999806513186)
# ('RB: fatP37.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: scurryabout -- earlyworms -- mapping_weight=', 0.20013260885729514)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: snakes -- eagles -- mapping_weignt=', 1)
# ('PO: eat -- say -- mapping_weignt=', 0.9736936216623769)
# ('PO: rats -- worms -- mapping_weignt=', 1)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: hiss -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: slither -- early -- mapping_weignt=', 0.941911714149796)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: think -- majestic -- mapping_weignt=', 0.408209906505278)
# ('PO: juicy -- in -- mapping_weignt=', 0.4570733332395104)
# ('PO: cunning -- NONE -- mapping_weignt=', 0.0)
# ('PO: love -- NONE -- mapping_weignt=', 0.0)
# ('PO: spotted -- jump -- mapping_weignt=', 0.8411868549165706)
# ('PO: at -- NONE -- mapping_weignt=', 0.0)
# ('PO: danger -- deer -- mapping_weignt=', 0.13472234555738308)
# ('PO: slender -- NONE -- mapping_weignt=', 0.0)
# ('PO: rattle -- NONE -- mapping_weignt=', 0.0)
# ('PO: towards -- NONE -- mapping_weignt=', 0.0)
# ('PO: traps -- NONE -- mapping_weignt=', 0.0)
# ('PO: quietly -- NONE -- mapping_weignt=', 0.0)
# ('PO: wobble -- spot -- mapping_weignt=', 1)
# ('PO: hairy -- NONE -- mapping_weignt=', 0.0)
# ('PO: fat -- into -- mapping_weignt=', 1)
# ('PO: scurry -- male -- mapping_weignt=', 0.815022642975067)
# ('PO: about -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 4
# retrieval successful
#
#
# Mappings:
#
# ('P: P00 -- NONE -- mapping_weight=', 0.0)
# ('P: P01 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P02 -- NONE -- mapping_weight=', 0.0)
# ('P: P03.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P03 -- NONE -- mapping_weight=', 0.0)
# ('P: P04.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P04 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P05 -- NONE -- mapping_weight=', 0.0)
# ('P: P06.1 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P06.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P06 -- NONE -- mapping_weight=', 0.0)
# ('P: P07.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P07 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: chasecats -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: barkobj -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: growlobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: bitecats -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP03.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: smallcats -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: biteP04.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: growlP05.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fromwater -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: awayP06.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detkitten -- NONE -- mapping_weight=', 0.0)
# ('RB: stayP06.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fluffycats -- NONE -- mapping_weight=', 0.0)
# ('RB: cuteP07.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: dogs -- lions -- mapping_weignt=', 0.4599710460033329)
# ('PO: chase -- NONE -- mapping_weignt=', 0.0)
# ('PO: cats -- deer -- mapping_weignt=', 0.4185210163642257)
# ('PO: hungry -- glide -- mapping_weignt=', 0.7949619622264374)
# ('PO: bark -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- majestic -- mapping_weignt=', 0.285852263746437)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: small -- in -- mapping_weignt=', 0.9897557330361754)
# ('PO: at -- NONE -- mapping_weignt=', 0.0)
# ('PO: strangers -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: from -- NONE -- mapping_weignt=', 0.0)
# ('PO: water -- NONE -- mapping_weignt=', 0.0)
# ('PO: away -- NONE -- mapping_weignt=', 0.0)
# ('PO: kitten -- NONE -- mapping_weignt=', 0.0)
# ('PO: stay -- NONE -- mapping_weignt=', 0.0)
# ('PO: fluffy -- NONE -- mapping_weignt=', 0.0)
# ('PO: cute -- NONE -- mapping_weignt=', 0.0)
# ('PO: purr -- NONE -- mapping_weignt=', 0.0)
# ('PO: softly -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 5
# retrieval successful
#
#
# Mappings:
#
# ('P: P10 -- NONE -- mapping_weight=', 0.0)
# ('P: P11 -- P31 -- mapping_weight=', 0.06080101039405872)
# ('P: P12 -- P12 -- mapping_weight=', 0.5001922431851608)
# ('P: P13.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P13 -- NONE -- mapping_weight=', 0.0)
# ('P: P14.1 -- P34.1 -- mapping_weight=', 0.011665948030435866)
# ('P: P14 -- NONE -- mapping_weight=', 0.0)
# ('P: P15.1 -- P15.1 -- mapping_weight=', 0.9899148853795916)
# ('P: P15.2 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P15 -- P15 -- mapping_weight=', 1)
# ('P: P16.1 -- P16.1 -- mapping_weight=', 0.8720922244842585)
# ('P: P16.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P16 -- NONE -- mapping_weight=', 0.0)
# ('P: P17.1 -- P34.1 -- mapping_weight=', 0.021720598273881907)
# ('P: P17 -- NONE -- mapping_weight=', 0.0)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: angrylions -- NONE -- mapping_weight=', 0.0)
# ('RB: roarobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detdeer -- detdeer -- mapping_weight=', 0.18090629765916455)
# ('RB: jumpobj -- jumpobj -- mapping_weight=', 1)
# ('RB: biglions -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: huntdeer -- huntdeer -- mapping_weight=', 1)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: knowP13.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: fastdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: bulkylions -- NONE -- mapping_weight=', 0.0)
# ('RB: stalkP14.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: malelions -- malelions -- mapping_weight=', 0.8069999806513186)
# ('RB: inanger -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: majesticP15.1 -- majesticP15.1 -- mapping_weight=', 1)
# ('RB: roarP15.2 -- roarP15.2 -- mapping_weight=', 1)
# ('RB: intodarkness -- intodarkness -- mapping_weight=', 0.7343467198141006)
# ('RB: quicklyP16.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: runP16.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: timiddeer -- hissobj -- mapping_weight=', 0.15591107749607205)
# ('RB: beautifulP17.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: grazehappily -- angrysnakes -- mapping_weight=', 0.7362354370218196)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: lions -- lions -- mapping_weignt=', 0.4599710460033329)
# ('PO: hunt -- hunt -- mapping_weignt=', 1)
# ('PO: deer -- deer -- mapping_weignt=', 0.4185210163642257)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: roar -- roar -- mapping_weignt=', 0.6715284395284402)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: jump -- jump -- mapping_weignt=', 0.8411868549165706)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: know -- NONE -- mapping_weignt=', 0.0)
# ('PO: fast -- NONE -- mapping_weignt=', 0.0)
# ('PO: bulky -- NONE -- mapping_weignt=', 0.0)
# ('PO: stalk -- NONE -- mapping_weignt=', 0.0)
# ('PO: male -- male -- mapping_weignt=', 0.815022642975067)
# ('PO: in -- in -- mapping_weignt=', 0.9897557330361754)
# ('PO: anger -- anger -- mapping_weignt=', 1)
# ('PO: majestic -- majestic -- mapping_weignt=', 0.408209906505278)
# ('PO: into -- into -- mapping_weignt=', 1)
# ('PO: darkness -- darkness -- mapping_weignt=', 1)
# ('PO: quickly -- NONE -- mapping_weignt=', 0.0)
# ('PO: run -- NONE -- mapping_weignt=', 0.0)
# ('PO: timid -- NONE -- mapping_weignt=', 0.0)
# ('PO: beautiful -- NONE -- mapping_weignt=', 0.0)
# ('PO: graze -- angry -- mapping_weignt=', 0.0036633084546921152)
# ('PO: happily -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 6
# retrieval successful
#
#
# Mappings:
#
# ('P: P00 -- NONE -- mapping_weight=', 0.0)
# ('P: P01 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P02 -- NONE -- mapping_weight=', 0.0)
# ('P: P03.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P03 -- NONE -- mapping_weight=', 0.0)
# ('P: P04.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P04 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P05 -- NONE -- mapping_weight=', 0.0)
# ('P: P06.1 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P06.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P06 -- NONE -- mapping_weight=', 0.0)
# ('P: P07.1 -- P24.1 -- mapping_weight=', 0.769762517544102)
# ('P: P07 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: chasecats -- easyworms -- mapping_weight=', 0.0392168740678845)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: barkobj -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: growlobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: bitecats -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP03.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: smallcats -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: biteP04.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: growlP05.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fromwater -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: awayP06.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: detkitten -- NONE -- mapping_weight=', 0.0)
# ('RB: stayP06.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fluffycats -- NONE -- mapping_weight=', 0.0)
# ('RB: cuteP07.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: dogs -- lions -- mapping_weignt=', 0.4599710460033329)
# ('PO: chase -- NONE -- mapping_weignt=', 0.0)
# ('PO: cats -- deer -- mapping_weignt=', 0.4185210163642257)
# ('PO: hungry -- glide -- mapping_weignt=', 0.7949619622264374)
# ('PO: bark -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- majestic -- mapping_weignt=', 0.285852263746437)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: small -- in -- mapping_weignt=', 0.9897557330361754)
# ('PO: at -- NONE -- mapping_weignt=', 0.0)
# ('PO: strangers -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: from -- easy -- mapping_weignt=', 0.6657128520075799)
# ('PO: water -- water -- mapping_weignt=', 0.438932408441743)
# ('PO: away -- away -- mapping_weignt=', 0.07460578706353171)
# ('PO: kitten -- NONE -- mapping_weignt=', 0.0)
# ('PO: stay -- NONE -- mapping_weignt=', 0.0)
# ('PO: fluffy -- NONE -- mapping_weignt=', 0.0)
# ('PO: cute -- NONE -- mapping_weignt=', 0.0)
# ('PO: purr -- NONE -- mapping_weignt=', 0.0)
# ('PO: softly -- worms -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 7
# retrieval successful
#
#
# Mappings:
#
# ('P: P00 -- NONE -- mapping_weight=', 0.0)
# ('P: P01 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P02 -- NONE -- mapping_weight=', 0.0)
# ('P: P03.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P03 -- NONE -- mapping_weight=', 0.0)
# ('P: P04.1 -- P34.1 -- mapping_weight=', 0.7257368682710755)
# ('P: P04 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P05 -- NONE -- mapping_weight=', 0.0)
# ('P: P06.1 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P06.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P06 -- NONE -- mapping_weight=', 0.0)
# ('P: P07.1 -- P24.1 -- mapping_weight=', 0.769762517544102)
# ('P: P07 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: chasecats -- easyworms -- mapping_weight=', 0.0392168740678845)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: barkobj -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: growlobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: bitecats -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP03.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: smallcats -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: biteP04.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: growlP05.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fromwater -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: awayP06.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: detkitten -- NONE -- mapping_weight=', 0.0)
# ('RB: stayP06.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fluffycats -- juicyrats -- mapping_weight=', 0.020176945887708523)
# ('RB: cuteP07.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: dogs -- rats -- mapping_weignt=', 1)
# ('PO: chase -- NONE -- mapping_weignt=', 0.0)
# ('PO: cats -- deer -- mapping_weignt=', 0.4185210163642257)
# ('PO: hungry -- glide -- mapping_weignt=', 0.7949619622264374)
# ('PO: bark -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- juicy -- mapping_weignt=', 0.958688742246794)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: small -- in -- mapping_weignt=', 0.9897557330361754)
# ('PO: at -- NONE -- mapping_weignt=', 0.0)
# ('PO: strangers -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: from -- easy -- mapping_weignt=', 0.6657128520075799)
# ('PO: water -- water -- mapping_weignt=', 0.438932408441743)
# ('PO: away -- away -- mapping_weignt=', 0.07460578706353171)
# ('PO: kitten -- NONE -- mapping_weignt=', 0.0)
# ('PO: stay -- NONE -- mapping_weignt=', 0.0)
# ('PO: fluffy -- NONE -- mapping_weignt=', 0.0)
# ('PO: cute -- NONE -- mapping_weignt=', 0.0)
# ('PO: purr -- NONE -- mapping_weignt=', 0.0)
# ('PO: softly -- worms -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 8
# retrieval successful
#
#
# Mappings:
#
# ('P: P00 -- P12 -- mapping_weight=', 0.2756089487228518)
# ('P: P01 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P02 -- NONE -- mapping_weight=', 0.0)
# ('P: P03.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P03 -- NONE -- mapping_weight=', 0.0)
# ('P: P04.1 -- P34.1 -- mapping_weight=', 0.7257368682710755)
# ('P: P04 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P05.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P05 -- NONE -- mapping_weight=', 0.0)
# ('P: P06.1 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P06.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P06 -- NONE -- mapping_weight=', 0.0)
# ('P: P07.1 -- P24.1 -- mapping_weight=', 0.769762517544102)
# ('P: P07 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: chasecats -- easyworms -- mapping_weight=', 0.0392168740678845)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: barkobj -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: growlobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: bitecats -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP03.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: smallcats -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: biteP04.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: growlP05.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fromwater -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: awayP06.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: detkitten -- NONE -- mapping_weight=', 0.0)
# ('RB: stayP06.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fluffycats -- detdeer -- mapping_weight=', 0.3657334242126127)
# ('RB: cuteP07.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: dogs -- rats -- mapping_weignt=', 1)
# ('PO: chase -- NONE -- mapping_weignt=', 0.0)
# ('PO: cats -- deer -- mapping_weignt=', 1)
# ('PO: hungry -- glide -- mapping_weignt=', 0.7949619622264374)
# ('PO: bark -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- juicy -- mapping_weignt=', 0.958688742246794)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: small -- in -- mapping_weignt=', 0.9897557330361754)
# ('PO: at -- NONE -- mapping_weignt=', 0.0)
# ('PO: strangers -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- jump -- mapping_weignt=', 0.44211672145299563)
# ('PO: from -- easy -- mapping_weignt=', 0.6657128520075799)
# ('PO: water -- water -- mapping_weignt=', 0.438932408441743)
# ('PO: away -- away -- mapping_weignt=', 0.07460578706353171)
# ('PO: kitten -- NONE -- mapping_weignt=', 0.0)
# ('PO: stay -- NONE -- mapping_weignt=', 0.0)
# ('PO: fluffy -- NONE -- mapping_weignt=', 0.0)
# ('PO: cute -- NONE -- mapping_weignt=', 0.0)
# ('PO: purr -- NONE -- mapping_weignt=', 0.0)
# ('PO: softly -- worms -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 9
# retrieval successful
#
#
# Mappings:
#
# ('P: P20 -- P30 -- mapping_weight=', 0.7635411027995642)
# ('P: P21 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P22 -- P32 -- mapping_weight=', 0.0767603452458639)
# ('P: P23.1 -- P23.1 -- mapping_weight=', 0.8335990966560927)
# ('P: P23 -- P23 -- mapping_weight=', 1)
# ('P: P24.1 -- P24.1 -- mapping_weight=', 0.769762517544102)
# ('P: P24 -- P17 -- mapping_weight=', 0.14382124127163598)
# ('P: P25.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P25.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P25 -- NONE -- mapping_weight=', 0.0)
# ('P: P26.1 -- P17.1 -- mapping_weight=', 0.19091653824966764)
# ('P: P26.2 -- P15.2 -- mapping_weight=', 0.08595239172931407)
# ('P: P26 -- NONE -- mapping_weight=', 0.0)
# ('P: P27.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P27 -- P34 -- mapping_weight=', 0.9360670509932528)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: eatworms -- eatrats -- mapping_weight=', 0.18929425664974864)
# ('RB: majesticeagles -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: glideobj -- detsnakes -- mapping_weight=', 0.0002800132849172471)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: flyobj -- NONE -- mapping_weight=', 0.0)
# ('RB: earlyworms -- earlyworms -- mapping_weight=', 0.20013260885729514)
# ('RB: spoteagles -- spoteagles -- mapping_weight=', 0.24997693098928844)
# ('RB: detworms -- detworms -- mapping_weight=', 0.6164165533818338)
# ('RB: sayP23.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: easyworms -- grazehappily -- mapping_weight=', 0.20225795835297702)
# ('RB: wiseeagles -- timiddeer -- mapping_weight=', 0.8772401062669499)
# ('RB: catchP24.1 -- majesticP15.1 -- mapping_weight=', 0.06423808666486676)
# ('RB: baldeagles -- bigsnakes -- mapping_weight=', 0.601652582623153)
# ('RB: thesky -- NONE -- mapping_weight=', 0.0)
# ('RB: oldP25.1 -- loveP34.1 -- mapping_weight=', 0.816817237687675)
# ('RB: scanP25.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fromunder -- NONE -- mapping_weight=', 0.0)
# ('RB: slowlyP26.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detworms -- NONE -- mapping_weight=', 0.0)
# ('RB: crawlP26.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: dullworms -- eatrats -- mapping_weight=', 0.028074409275981174)
# ('RB: slowP27.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: wanderaimlessly -- cunningsnakes -- mapping_weight=', 0.21307273666640475)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: eagles -- eagles -- mapping_weignt=', 1)
# ('PO: eat -- beautiful -- mapping_weignt=', 0.504123058598203)
# ('PO: worms -- worms -- mapping_weignt=', 1)
# ('PO: majestic -- majestic -- mapping_weignt=', 0.285852263746437)
# ('PO: glide -- glide -- mapping_weignt=', 0.7949619622264374)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: fly -- NONE -- mapping_weignt=', 0.0)
# ('PO: early -- early -- mapping_weignt=', 0.941911714149796)
# ('PO: spot -- spot -- mapping_weignt=', 1)
# ('PO: say -- say -- mapping_weignt=', 0.9736936216623769)
# ('PO: easy -- easy -- mapping_weignt=', 0.6657128520075799)
# ('PO: wise -- timid -- mapping_weignt=', 0.5243693317851892)
# ('PO: catch -- NONE -- mapping_weignt=', 0.0)
# ('PO: bald -- hiss -- mapping_weignt=', 0.10250581844397648)
# ('PO: the -- graze -- mapping_weignt=', 0.8048059687304927)
# ('PO: sky -- NONE -- mapping_weignt=', 0.0)
# ('PO: old -- NONE -- mapping_weignt=', 0.0)
# ('PO: scan -- NONE -- mapping_weignt=', 0.0)
# ('PO: from -- NONE -- mapping_weignt=', 0.0)
# ('PO: under -- NONE -- mapping_weignt=', 0.0)
# ('PO: slowly -- NONE -- mapping_weignt=', 0.0)
# ('PO: crawl -- NONE -- mapping_weignt=', 0.0)
# ('PO: dull -- love -- mapping_weignt=', 0.42746244735038885)
# ('PO: slow -- NONE -- mapping_weignt=', 0.0)
# ('PO: wander -- NONE -- mapping_weignt=', 0.0)
# ('PO: aimlessly -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 10
# retrieval successful
#
#
# Mappings:
#
# ('P: P10 -- NONE -- mapping_weight=', 0.0)
# ('P: P11 -- P31 -- mapping_weight=', 0.06080101039405872)
# ('P: P12 -- P12 -- mapping_weight=', 0.5001922431851608)
# ('P: P13.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P13 -- NONE -- mapping_weight=', 0.0)
# ('P: P14.1 -- P27.1 -- mapping_weight=', 0.5550217960222136)
# ('P: P14 -- P27 -- mapping_weight=', 0.8017018333820236)
# ('P: P15.1 -- P15.1 -- mapping_weight=', 0.9899148853795916)
# ('P: P15.2 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P15 -- P15 -- mapping_weight=', 1)
# ('P: P16.1 -- P16.1 -- mapping_weight=', 0.8720922244842585)
# ('P: P16.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P16 -- NONE -- mapping_weight=', 0.0)
# ('P: P17.1 -- P17.1 -- mapping_weight=', 0.19091653824966764)
# ('P: P17 -- P17 -- mapping_weight=', 0.14382124127163598)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: angrylions -- atdanger -- mapping_weight=', 0.6384628653613373)
# ('RB: roarobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detdeer -- detdeer -- mapping_weight=', 0.3657334242126127)
# ('RB: jumpobj -- jumpobj -- mapping_weight=', 1)
# ('RB: biglions -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: huntdeer -- huntdeer -- mapping_weight=', 1)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: knowP13.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: fastdeer -- wanderaimlessly -- mapping_weight=', 0.555786101717748)
# ('RB: bulkylions -- dullworms -- mapping_weight=', 0.4812788439449498)
# ('RB: stalkP14.1 -- slowP27.1 -- mapping_weight=', 1)
# ('RB: malelions -- malelions -- mapping_weight=', 0.8069999806513186)
# ('RB: inanger -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: majesticP15.1 -- majesticP15.1 -- mapping_weight=', 1)
# ('RB: roarP15.2 -- roarP15.2 -- mapping_weight=', 1)
# ('RB: intodarkness -- intodarkness -- mapping_weight=', 0.7343467198141006)
# ('RB: quicklyP16.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: runP16.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: timiddeer -- timiddeer -- mapping_weight=', 0.8772401062669499)
# ('RB: beautifulP17.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: grazehappily -- angrysnakes -- mapping_weight=', 0.7362354370218196)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: lions -- aimlessly -- mapping_weignt=', 1)
# ('PO: hunt -- hunt -- mapping_weignt=', 1)
# ('PO: deer -- deer -- mapping_weignt=', 1)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: roar -- roar -- mapping_weignt=', 0.6715284395284402)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: jump -- jump -- mapping_weignt=', 0.8411868549165706)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: know -- NONE -- mapping_weignt=', 0.0)
# ('PO: fast -- NONE -- mapping_weignt=', 0.0)
# ('PO: bulky -- wander -- mapping_weignt=', 0.11725851995512274)
# ('PO: stalk -- NONE -- mapping_weignt=', 0.0)
# ('PO: male -- male -- mapping_weignt=', 0.815022642975067)
# ('PO: in -- in -- mapping_weignt=', 0.9897557330361754)
# ('PO: anger -- anger -- mapping_weignt=', 1)
# ('PO: majestic -- majestic -- mapping_weignt=', 0.408209906505278)
# ('PO: into -- into -- mapping_weignt=', 1)
# ('PO: darkness -- darkness -- mapping_weignt=', 1)
# ('PO: quickly -- NONE -- mapping_weignt=', 0.0)
# ('PO: run -- NONE -- mapping_weignt=', 0.0)
# ('PO: timid -- timid -- mapping_weignt=', 0.5243693317851892)
# ('PO: beautiful -- beautiful -- mapping_weignt=', 0.504123058598203)
# ('PO: graze -- graze -- mapping_weignt=', 0.8048059687304927)
# ('PO: happily -- danger -- mapping_weignt=', 0.7193311417368325)
#
#
# ************************* Cycle: 11
# retrieval successful
#
#
# Mappings:
#
# ('P: P30 -- P30 -- mapping_weight=', 0.7635411027995642)
# ('P: P31 -- P23.1 -- mapping_weight=', 0.8335990966560927)
# ('P: P32 -- P12 -- mapping_weight=', 0.5001922431851608)
# ('P: P33.1 -- P33.1 -- mapping_weight=', 0.7466541533774558)
# ('P: P33 -- P23 -- mapping_weight=', 1)
# ('P: P34.1 -- P34.1 -- mapping_weight=', 0.7257368682710755)
# ('P: P34 -- P34 -- mapping_weight=', 0.9360670509932528)
# ('P: P35.1 -- P14.1 -- mapping_weight=', 0.02882640866741338)
# ('P: P35.2 -- P15.2 -- mapping_weight=', 0.4056569173422296)
# ('P: P35 -- P15 -- mapping_weight=', 1)
# ('P: P36.1 -- P16.1 -- mapping_weight=', 0.8720922244842585)
# ('P: P36.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P36 -- NONE -- mapping_weight=', 0.0)
# ('P: P37.1 -- P15.1 -- mapping_weight=', 0.9899148853795916)
# ('P: P37 -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- eatrats -- mapping_weight=', 0.18929425664974864)
# ('RB: angrysnakes -- angrysnakes -- mapping_weight=', 0.7362354370218196)
# ('RB: hissobj -- hissobj -- mapping_weight=', 0.15591107749607205)
# ('RB: detsnakes -- detsnakes -- mapping_weight=', 0.0002800132849172471)
# ('RB: slitherobj -- hungrydogs -- mapping_weight=', 1)
# ('RB: bigsnakes -- bigsnakes -- mapping_weight=', 0.601652582623153)
# ('RB: eatrats -- eatrats -- mapping_weight=', 0.028074409275981174)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP33.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: juicyrats -- inanger -- mapping_weight=', 0.1174741689685893)
# ('RB: cunningsnakes -- fastdeer -- mapping_weight=', 0.27894688253055044)
# ('RB: loveP34.1 -- stalkP14.1 -- mapping_weight=', 1)
# ('RB: spottedsnakes -- jumpobj -- mapping_weight=', 1)
# ('RB: atdanger -- atdanger -- mapping_weight=', 0.6384628653613373)
# ('RB: slenderP35.1 -- roarP15.2 -- mapping_weight=', 1)
# ('RB: rattleP35.2 -- majesticP15.1 -- mapping_weight=', 1)
# ('RB: towardstraps -- intodarkness -- mapping_weight=', 0.7343467198141006)
# ('RB: quietlyP36.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detrats -- detworms -- mapping_weight=', 0.6164165533818338)
# ('RB: wobbleP36.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: hairyrats -- malelions -- mapping_weight=', 0.8069999806513186)
# ('RB: fatP37.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: scurryabout -- earlyworms -- mapping_weight=', 0.20013260885729514)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: snakes -- eagles -- mapping_weignt=', 1)
# ('PO: eat -- say -- mapping_weignt=', 0.9736936216623769)
# ('PO: rats -- worms -- mapping_weignt=', 1)
# ('PO: angry -- angry -- mapping_weignt=', 0.0036633084546921152)
# ('PO: hiss -- hiss -- mapping_weignt=', 0.16265979905856193)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: slither -- early -- mapping_weignt=', 0.941911714149796)
# ('PO: big -- big -- mapping_weignt=', 0.06463561456184085)
# ('PO: think -- majestic -- mapping_weignt=', 0.408209906505278)
# ('PO: juicy -- juicy -- mapping_weignt=', 0.958688742246794)
# ('PO: cunning -- stalk -- mapping_weignt=', 0.12545243663403535)
# ('PO: love -- love -- mapping_weignt=', 0.42746244735038885)
# ('PO: spotted -- jump -- mapping_weignt=', 0.8411868549165706)
# ('PO: at -- NONE -- mapping_weignt=', 0.0)
# ('PO: danger -- danger -- mapping_weignt=', 0.7193311417368325)
# ('PO: slender -- NONE -- mapping_weignt=', 0.0)
# ('PO: rattle -- NONE -- mapping_weignt=', 0.0)
# ('PO: towards -- NONE -- mapping_weignt=', 0.0)
# ('PO: traps -- dogs -- mapping_weignt=', 0.02401408414149503)
# ('PO: quietly -- fast -- mapping_weignt=', 0.05873803684503612)
# ('PO: wobble -- spot -- mapping_weignt=', 1)
# ('PO: hairy -- NONE -- mapping_weignt=', 0.0)
# ('PO: fat -- into -- mapping_weignt=', 1)
# ('PO: scurry -- male -- mapping_weignt=', 0.815022642975067)
# ('PO: about -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 12
# retrieval successful
#
#
# Mappings:
#
# ('P: P10 -- P00 -- mapping_weight=', 0.4983515998782604)
# ('P: P11 -- P31 -- mapping_weight=', 0.06080101039405872)
# ('P: P12 -- P12 -- mapping_weight=', 0.5001922431851608)
# ('P: P13.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P13 -- NONE -- mapping_weight=', 0.0)
# ('P: P14.1 -- P27.1 -- mapping_weight=', 0.5550217960222136)
# ('P: P14 -- P27 -- mapping_weight=', 0.8017018333820236)
# ('P: P15.1 -- P15.1 -- mapping_weight=', 0.9899148853795916)
# ('P: P15.2 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P15 -- P15 -- mapping_weight=', 1)
# ('P: P16.1 -- P16.1 -- mapping_weight=', 0.8720922244842585)
# ('P: P16.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P16 -- NONE -- mapping_weight=', 0.0)
# ('P: P17.1 -- P17.1 -- mapping_weight=', 0.19091653824966764)
# ('P: P17 -- P17 -- mapping_weight=', 0.14382124127163598)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: angrylions -- atdanger -- mapping_weight=', 0.6384628653613373)
# ('RB: roarobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detdeer -- detdeer -- mapping_weight=', 0.3657334242126127)
# ('RB: jumpobj -- jumpobj -- mapping_weight=', 1)
# ('RB: biglions -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: huntdeer -- huntdeer -- mapping_weight=', 1)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: knowP13.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: fastdeer -- wanderaimlessly -- mapping_weight=', 0.555786101717748)
# ('RB: bulkylions -- chasecats -- mapping_weight=', 0.7116299112942261)
# ('RB: stalkP14.1 -- slowP27.1 -- mapping_weight=', 1)
# ('RB: malelions -- malelions -- mapping_weight=', 0.8069999806513186)
# ('RB: inanger -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: majesticP15.1 -- majesticP15.1 -- mapping_weight=', 1)
# ('RB: roarP15.2 -- roarP15.2 -- mapping_weight=', 1)
# ('RB: intodarkness -- intodarkness -- mapping_weight=', 0.7343467198141006)
# ('RB: quicklyP16.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: runP16.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: timiddeer -- timiddeer -- mapping_weight=', 0.8772401062669499)
# ('RB: beautifulP17.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: grazehappily -- detdogs -- mapping_weight=', 0.8687185469400412)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: lions -- aimlessly -- mapping_weignt=', 1)
# ('PO: hunt -- hunt -- mapping_weignt=', 1)
# ('PO: deer -- deer -- mapping_weignt=', 1)
# ('PO: angry -- chase -- mapping_weignt=', 0.3115668716168163)
# ('PO: roar -- roar -- mapping_weignt=', 0.6715284395284402)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: jump -- jump -- mapping_weignt=', 0.8411868549165706)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: know -- NONE -- mapping_weignt=', 0.0)
# ('PO: fast -- fast -- mapping_weignt=', 0.05873803684503612)
# ('PO: bulky -- wander -- mapping_weignt=', 0.11725851995512274)
# ('PO: stalk -- stalk -- mapping_weignt=', 0.12545243663403535)
# ('PO: male -- male -- mapping_weignt=', 0.815022642975067)
# ('PO: in -- in -- mapping_weignt=', 0.9897557330361754)
# ('PO: anger -- anger -- mapping_weignt=', 1)
# ('PO: majestic -- majestic -- mapping_weignt=', 0.408209906505278)
# ('PO: into -- into -- mapping_weignt=', 1)
# ('PO: darkness -- darkness -- mapping_weignt=', 1)
# ('PO: quickly -- NONE -- mapping_weignt=', 0.0)
# ('PO: run -- NONE -- mapping_weignt=', 0.0)
# ('PO: timid -- timid -- mapping_weignt=', 0.5243693317851892)
# ('PO: beautiful -- beautiful -- mapping_weignt=', 0.504123058598203)
# ('PO: graze -- graze -- mapping_weignt=', 0.8048059687304927)
# ('PO: happily -- dogs -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 13
# retrieval successful
#
#
# Mappings:
#
# ('P: P20 -- P30 -- mapping_weight=', 0.7635411027995642)
# ('P: P21 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P22 -- P32 -- mapping_weight=', 0.0767603452458639)
# ('P: P23.1 -- P23.1 -- mapping_weight=', 0.8335990966560927)
# ('P: P23 -- P23 -- mapping_weight=', 1)
# ('P: P24.1 -- P24.1 -- mapping_weight=', 0.769762517544102)
# ('P: P24 -- P17 -- mapping_weight=', 0.14382124127163598)
# ('P: P25.1 -- P35.1 -- mapping_weight=', 0.00642196214291996)
# ('P: P25.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P25 -- NONE -- mapping_weight=', 0.0)
# ('P: P26.1 -- P17.1 -- mapping_weight=', 0.19091653824966764)
# ('P: P26.2 -- P15.2 -- mapping_weight=', 0.08595239172931407)
# ('P: P26 -- P06 -- mapping_weight=', 0.8884393971839831)
# ('P: P27.1 -- P27.1 -- mapping_weight=', 0.5550217960222136)
# ('P: P27 -- P34 -- mapping_weight=', 0.9360670509932528)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: eatworms -- eatrats -- mapping_weight=', 0.18929425664974864)
# ('RB: majesticeagles -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: glideobj -- detlions -- mapping_weight=', 0.006194226399122336)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: flyobj -- NONE -- mapping_weight=', 0.0)
# ('RB: earlyworms -- earlyworms -- mapping_weight=', 0.20013260885729514)
# ('RB: spoteagles -- spoteagles -- mapping_weight=', 0.24997693098928844)
# ('RB: detworms -- detworms -- mapping_weight=', 0.6164165533818338)
# ('RB: sayP23.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: easyworms -- grazehappily -- mapping_weight=', 0.20225795835297702)
# ('RB: wiseeagles -- timiddeer -- mapping_weight=', 0.8772401062669499)
# ('RB: catchP24.1 -- stalkP14.1 -- mapping_weight=', 0.14418369422522437)
# ('RB: baldeagles -- bigsnakes -- mapping_weight=', 0.601652582623153)
# ('RB: thesky -- detkitten -- mapping_weight=', 1)
# ('RB: oldP25.1 -- loveP34.1 -- mapping_weight=', 0.816817237687675)
# ('RB: scanP25.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fromunder -- huntdeer -- mapping_weight=', 0.5257522366441296)
# ('RB: slowlyP26.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: detworms -- NONE -- mapping_weight=', 0.0)
# ('RB: crawlP26.2 -- stayP06.2 -- mapping_weight=', 1)
# ('RB: dullworms -- dullworms -- mapping_weight=', 0.4812788439449498)
# ('RB: slowP27.1 -- slowP27.1 -- mapping_weight=', 1)
# ('RB: wanderaimlessly -- wanderaimlessly -- mapping_weight=', 0.555786101717748)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: eagles -- eagles -- mapping_weignt=', 1)
# ('PO: eat -- beautiful -- mapping_weignt=', 0.504123058598203)
# ('PO: worms -- worms -- mapping_weignt=', 1)
# ('PO: majestic -- majestic -- mapping_weignt=', 0.285852263746437)
# ('PO: glide -- glide -- mapping_weignt=', 0.7949619622264374)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: fly -- NONE -- mapping_weignt=', 0.0)
# ('PO: early -- early -- mapping_weignt=', 0.941911714149796)
# ('PO: spot -- spot -- mapping_weignt=', 1)
# ('PO: say -- say -- mapping_weignt=', 0.9736936216623769)
# ('PO: easy -- easy -- mapping_weignt=', 0.6657128520075799)
# ('PO: wise -- timid -- mapping_weignt=', 0.5243693317851892)
# ('PO: catch -- NONE -- mapping_weignt=', 0.0)
# ('PO: bald -- hiss -- mapping_weignt=', 0.10250581844397648)
# ('PO: the -- graze -- mapping_weignt=', 0.8048059687304927)
# ('PO: sky -- water -- mapping_weignt=', 0.0700994807296335)
# ('PO: old -- at -- mapping_weignt=', 0.0007956721958240954)
# ('PO: scan -- NONE -- mapping_weignt=', 0.0)
# ('PO: from -- NONE -- mapping_weignt=', 0.0)
# ('PO: under -- NONE -- mapping_weignt=', 0.0)
# ('PO: slowly -- NONE -- mapping_weignt=', 0.0)
# ('PO: crawl -- stay -- mapping_weignt=', 0.39155093172223565)
# ('PO: dull -- dull -- mapping_weignt=', 0.5624023059457998)
# ('PO: slow -- slow -- mapping_weignt=', 0.23271172407631974)
# ('PO: wander -- rattle -- mapping_weignt=', 0.185514986428143)
# ('PO: aimlessly -- aimlessly -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 14
# retrieval successful
#
#
# Mappings:
#
# ('P: P00 -- P00 -- mapping_weight=', 0.4983515998782604)
# ('P: P01 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P02 -- NONE -- mapping_weight=', 0.0)
# ('P: P03.1 -- P13.1 -- mapping_weight=', 0.7463945502139767)
# ('P: P03 -- P13 -- mapping_weight=', 0.028639443928327582)
# ('P: P04.1 -- P34.1 -- mapping_weight=', 0.7257368682710755)
# ('P: P04 -- P24 -- mapping_weight=', 0.702274678965179)
# ('P: P05.1 -- P24.1 -- mapping_weight=', 0.1054772754245767)
# ('P: P05.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P05 -- NONE -- mapping_weight=', 0.0)
# ('P: P06.1 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P06.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P06 -- P06 -- mapping_weight=', 0.8884393971839831)
# ('P: P07.1 -- P24.1 -- mapping_weight=', 0.769762517544102)
# ('P: P07 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- detdogs -- mapping_weight=', 0.8687185469400412)
# ('RB: chasecats -- chasecats -- mapping_weight=', 0.7116299112942261)
# ('RB: hungrydogs -- hungrydogs -- mapping_weight=', 1)
# ('RB: barkobj -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: growlobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- earlyworms -- mapping_weight=', 0.05561870312674348)
# ('RB: bitecats -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP03.1 -- sayP23.1 -- mapping_weight=', 0.18156167527711425)
# ('RB: smallcats -- detlions -- mapping_weight=', 0.8851962614078694)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: biteP04.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: growlP05.2 -- NONE -- mapping_weight=', 0.0)
# ('RB: fromwater -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: awayP06.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: detkitten -- detkitten -- mapping_weight=', 1)
# ('RB: stayP06.2 -- stayP06.2 -- mapping_weight=', 1)
# ('RB: fluffycats -- detdeer -- mapping_weight=', 0.3657334242126127)
# ('RB: cuteP07.1 -- catchP24.1 -- mapping_weight=', 1)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: dogs -- rats -- mapping_weignt=', 1)
# ('PO: chase -- chase -- mapping_weignt=', 0.3115668716168163)
# ('PO: cats -- deer -- mapping_weignt=', 1)
# ('PO: hungry -- glide -- mapping_weignt=', 0.7949619622264374)
# ('PO: bark -- bark -- mapping_weignt=', 0.8242440817559704)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- juicy -- mapping_weignt=', 0.958688742246794)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: small -- in -- mapping_weignt=', 0.9897557330361754)
# ...
# ('RB: smallcats -- detlions -- mapping_weight=', 0.8851962614078694)
# ('RB: bigdogs -- bigdogs -- mapping_weight=', 0.6641932078486426)
# ('RB: biteP04.1 -- beautifulP17.1 -- mapping_weight=', 1)
# ('RB: hungrydogs -- hungrydogs -- mapping_weight=', 0.621723091712013)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- slowlyP26.1 -- mapping_weight=', 1)
# ('RB: growlP05.2 -- growlP05.2 -- mapping_weight=', 0.3065908435260544)
# ('RB: fromwater -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: awayP06.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: detkitten -- detkitten -- mapping_weight=', 1)
# ('RB: stayP06.2 -- stayP06.2 -- mapping_weight=', 1)
# ('RB: fluffycats -- fluffycats -- mapping_weight=', 0.547585887743809)
# ('RB: cuteP07.1 -- catchP24.1 -- mapping_weight=', 1)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: dogs -- rats -- mapping_weignt=', 1)
# ('PO: chase -- think -- mapping_weignt=', 1)
# ('PO: cats -- deer -- mapping_weignt=', 1)
# ('PO: hungry -- slowly -- mapping_weignt=', 1)
# ('PO: bark -- bark -- mapping_weignt=', 1)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- growl -- mapping_weignt=', 1)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- think -- mapping_weignt=', 1)
# ('PO: small -- in -- mapping_weignt=', 1)
# ('PO: at -- at -- mapping_weignt=', 1)
# ('PO: strangers -- traps -- mapping_weignt=', 1)
# ('PO: angry -- angry -- mapping_weignt=', 0.9090665993129934)
# ('PO: from -- from -- mapping_weignt=', 1)
# ('PO: water -- water -- mapping_weignt=', 1)
# ('PO: away -- slither -- mapping_weignt=', 1)
# ('PO: kitten -- kitten -- mapping_weignt=', 1)
# ('PO: stay -- stay -- mapping_weignt=', 1)
# ('PO: fluffy -- roar -- mapping_weignt=', 1)
# ('PO: cute -- male -- mapping_weignt=', 0.908952547741432)
# ('PO: purr -- angry -- mapping_weignt=', 0.9588120979939195)
# ('PO: softly -- worms -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 97
# retrieval successful
#
#
# Mappings:
#
# ('P: P30 -- P30 -- mapping_weight=', 0.7635411027995642)
# ('P: P31 -- P23.1 -- mapping_weight=', 0.8335990966560927)
# ('P: P32 -- P12 -- mapping_weight=', 0.5001922431851608)
# ('P: P33.1 -- P33.1 -- mapping_weight=', 0.8600704257340284)
# ('P: P33 -- P23 -- mapping_weight=', 1)
# ('P: P34.1 -- P34.1 -- mapping_weight=', 0.7257368682710755)
# ('P: P34 -- P34 -- mapping_weight=', 0.9360670509932528)
# ('P: P35.1 -- P24.1 -- mapping_weight=', 0.3367253338888496)
# ('P: P35.2 -- P15.2 -- mapping_weight=', 0.4056569173422296)
# ('P: P35 -- P15 -- mapping_weight=', 1)
# ('P: P36.1 -- P16.1 -- mapping_weight=', 0.8720922244842585)
# ('P: P36.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P36 -- P06 -- mapping_weight=', 0.44622890645502955)
# ('P: P37.1 -- P15.1 -- mapping_weight=', 0.9899148853795916)
# ('P: P37 -- P37 -- mapping_weight=', 0.7479371817355509)
# ('RB: detsnakes -- detsnakes -- mapping_weight=', 1)
# ('RB: eatrats -- eatrats -- mapping_weight=', 0.990041784949664)
# ('RB: angrysnakes -- angrysnakes -- mapping_weight=', 0.7362354370218196)
# ('RB: hissobj -- detlions -- mapping_weight=', 1)
# ('RB: detsnakes -- detsnakes -- mapping_weight=', 0.0002800132849172471)
# ('RB: slitherobj -- hungrydogs -- mapping_weight=', 1)
# ('RB: bigsnakes -- bigsnakes -- mapping_weight=', 0.7956530113522673)
# ('RB: eatrats -- eatrats -- mapping_weight=', 0.6561636615638349)
# ('RB: detsnakes -- detsnakes -- mapping_weight=', 1)
# ('RB: thinkP33.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: juicyrats -- inanger -- mapping_weight=', 0.1174741689685893)
# ('RB: cunningsnakes -- fluffycats -- mapping_weight=', 0.547585887743809)
# ('RB: loveP34.1 -- stalkP14.1 -- mapping_weight=', 1)
# ('RB: spottedsnakes -- jumpobj -- mapping_weight=', 1)
# ('RB: atdanger -- atdanger -- mapping_weight=', 0.7545947215008659)
# ('RB: slenderP35.1 -- roarP15.2 -- mapping_weight=', 1)
# ('RB: rattleP35.2 -- majesticP15.1 -- mapping_weight=', 1)
# ('RB: towardstraps -- intodarkness -- mapping_weight=', 0.7343467198141006)
# ('RB: quietlyP36.1 -- quietlyP36.1 -- mapping_weight=', 1)
# ('RB: detrats -- detrats -- mapping_weight=', 1)
# ('RB: wobbleP36.2 -- wobbleP36.2 -- mapping_weight=', 1)
# ('RB: hairyrats -- malelions -- mapping_weight=', 0.8069999806513186)
# ('RB: fatP37.1 -- fatP37.1 -- mapping_weight=', 0.729419704990057)
# ('RB: scurryabout -- deteagles -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: snakes -- eagles -- mapping_weignt=', 1)
# ('PO: eat -- bark -- mapping_weignt=', 1)
# ('PO: rats -- worms -- mapping_weignt=', 1)
# ('PO: angry -- angry -- mapping_weignt=', 0.9794424918294858)
# ('PO: hiss -- hiss -- mapping_weignt=', 1)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: slither -- early -- mapping_weignt=', 1)
# ('PO: big -- big -- mapping_weignt=', 1.0)
# ('PO: think -- think -- mapping_weignt=', 1)
# ('PO: juicy -- juicy -- mapping_weignt=', 1)
# ('PO: cunning -- cunning -- mapping_weignt=', 1)
# ('PO: love -- glide -- mapping_weignt=', 1)
# ('PO: spotted -- jump -- mapping_weignt=', 1)
# ('PO: at -- the -- mapping_weignt=', 1)
# ('PO: danger -- danger -- mapping_weignt=', 1)
# ('PO: slender -- bite -- mapping_weignt=', 1)
# ('PO: rattle -- stay -- mapping_weignt=', 1)
# ('PO: towards -- towards -- mapping_weignt=', 0.9726903305676892)
# ('PO: traps -- traps -- mapping_weignt=', 1)
# ('PO: quietly -- quietly -- mapping_weignt=', 1)
# ('PO: wobble -- spot -- mapping_weignt=', 1)
# ('PO: hairy -- majestic -- mapping_weignt=', 1)
# ('PO: fat -- into -- mapping_weignt=', 1)
# ('PO: scurry -- old -- mapping_weignt=', 1)
# ('PO: about -- softly -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 98
# retrieval successful
#
#
# Mappings:
#
# ('P: P00 -- P00 -- mapping_weight=', 0.4983515998782604)
# ('P: P01 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P02 -- P02 -- mapping_weight=', 0.3400126868500247)
# ('P: P03.1 -- P03.1 -- mapping_weight=', 0.9156968694296097)
# ('P: P03 -- P03 -- mapping_weight=', 1)
# ('P: P04.1 -- P34.1 -- mapping_weight=', 0.7257368682710755)
# ('P: P04 -- P17 -- mapping_weight=', 0.748668763363731)
# ('P: P05.1 -- P17.1 -- mapping_weight=', 0.3283432386674977)
# ('P: P05.2 -- P05.2 -- mapping_weight=', 0.11647350046997337)
# ('P: P05 -- P05 -- mapping_weight=', 0.7211051035018983)
# ('P: P06.1 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P06.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P06 -- P06 -- mapping_weight=', 0.8884393971839831)
# ('P: P07.1 -- P24.1 -- mapping_weight=', 0.769762517544102)
# ('P: P07 -- P07 -- mapping_weight=', 0.7246052703329365)
# ('RB: detdogs -- detdogs -- mapping_weight=', 1)
# ('RB: chasecats -- chasecats -- mapping_weight=', 0.7116299112942261)
# ('RB: hungrydogs -- hungrydogs -- mapping_weight=', 1)
# ('RB: barkobj -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: detdogs -- detdogs -- mapping_weight=', 1)
# ('RB: growlobj -- detsnakes -- mapping_weight=', 1)
# ('RB: bigdogs -- bigdogs -- mapping_weight=', 0.47900046092002846)
# ('RB: bitecats -- bitecats -- mapping_weight=', 0.449115765402589)
# ('RB: detdogs -- detdogs -- mapping_weight=', 1)
# ('RB: thinkP03.1 -- crawlP26.2 -- mapping_weight=', 1)
# ('RB: smallcats -- detlions -- mapping_weight=', 0.8851962614078694)
# ('RB: bigdogs -- bigdogs -- mapping_weight=', 0.6641932078486426)
# ('RB: biteP04.1 -- beautifulP17.1 -- mapping_weight=', 1)
# ('RB: hungrydogs -- hungrydogs -- mapping_weight=', 0.621723091712013)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- slowlyP26.1 -- mapping_weight=', 1)
# ('RB: growlP05.2 -- growlP05.2 -- mapping_weight=', 0.3065908435260544)
# ('RB: fromwater -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: awayP06.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: detkitten -- detkitten -- mapping_weight=', 1)
# ('RB: stayP06.2 -- stayP06.2 -- mapping_weight=', 1)
# ('RB: fluffycats -- fluffycats -- mapping_weight=', 0.547585887743809)
# ('RB: cuteP07.1 -- catchP24.1 -- mapping_weight=', 1)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: dogs -- rats -- mapping_weignt=', 1)
# ('PO: chase -- think -- mapping_weignt=', 1)
# ('PO: cats -- deer -- mapping_weignt=', 1)
# ('PO: hungry -- slowly -- mapping_weignt=', 1)
# ('PO: bark -- bark -- mapping_weignt=', 1)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- growl -- mapping_weignt=', 1)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- think -- mapping_weignt=', 1)
# ('PO: small -- in -- mapping_weignt=', 1)
# ('PO: at -- at -- mapping_weignt=', 1)
# ('PO: strangers -- traps -- mapping_weignt=', 1)
# ('PO: angry -- angry -- mapping_weignt=', 0.9090665993129934)
# ('PO: from -- from -- mapping_weignt=', 1)
# ('PO: water -- water -- mapping_weignt=', 1)
# ('PO: away -- slither -- mapping_weignt=', 1)
# ('PO: kitten -- kitten -- mapping_weignt=', 1)
# ('PO: stay -- stay -- mapping_weignt=', 1)
# ('PO: fluffy -- roar -- mapping_weignt=', 1)
# ('PO: cute -- male -- mapping_weignt=', 1)
# ('PO: purr -- angry -- mapping_weignt=', 0.9588120979939195)
# ('PO: softly -- worms -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 99
# retrieval successful
#
#
# Mappings:
#
# ('P: P10 -- P00 -- mapping_weight=', 0.4983515998782604)
# ('P: P11 -- P11 -- mapping_weight=', 0.5449973662835356)
# ('P: P12 -- P12 -- mapping_weight=', 0.5001922431851608)
# ('P: P13.1 -- P33.1 -- mapping_weight=', 0.8600704257340284)
# ('P: P13 -- P13 -- mapping_weight=', 1)
# ('P: P14.1 -- P27.1 -- mapping_weight=', 0.5550217960222136)
# ('P: P14 -- P27 -- mapping_weight=', 0.8017018333820236)
# ('P: P15.1 -- P15.1 -- mapping_weight=', 0.9899148853795916)
# ('P: P15.2 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P15 -- P15 -- mapping_weight=', 1)
# ('P: P16.1 -- P16.1 -- mapping_weight=', 0.8720922244842585)
# ('P: P16.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P16 -- P16 -- mapping_weight=', 0.4329197061308325)
# ('P: P17.1 -- P17.1 -- mapping_weight=', 0.3283432386674977)
# ('P: P17 -- P17 -- mapping_weight=', 0.748668763363731)
# ('RB: detlions -- detlions -- mapping_weight=', 1)
# ('RB: huntdeer -- huntdeer -- mapping_weight=', 0.5257522366441296)
# ('RB: angrylions -- atdanger -- mapping_weight=', 0.7545947215008659)
# ('RB: roarobj -- deteagles -- mapping_weight=', 0.5184165938273776)
# ('RB: detdeer -- detdeer -- mapping_weight=', 1)
# ('RB: jumpobj -- jumpobj -- mapping_weight=', 1)
# ('RB: biglions -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: huntdeer -- huntdeer -- mapping_weight=', 1)
# ('RB: detlions -- detlions -- mapping_weight=', 0.8851962614078694)
# ('RB: knowP13.1 -- knowP13.1 -- mapping_weight=', 1)
# ('RB: fastdeer -- wanderaimlessly -- mapping_weight=', 0.555786101717748)
# ('RB: bulkylions -- chasecats -- mapping_weight=', 0.7116299112942261)
# ('RB: stalkP14.1 -- slowP27.1 -- mapping_weight=', 1)
# ('RB: malelions -- malelions -- mapping_weight=', 0.8069999806513186)
# ('RB: inanger -- detsnakes -- mapping_weight=', 1)
# ('RB: majesticP15.1 -- majesticP15.1 -- mapping_weight=', 1)
# ('RB: roarP15.2 -- roarP15.2 -- mapping_weight=', 1)
# ('RB: intodarkness -- detrats -- mapping_weight=', 1)
# ('RB: quicklyP16.1 -- scanP25.2 -- mapping_weight=', 1)
# ('RB: detdeer -- detdeer -- mapping_weight=', 1)
# ('RB: runP16.2 -- runP16.2 -- mapping_weight=', 1)
# ('RB: timiddeer -- timiddeer -- mapping_weight=', 0.8772401062669499)
# ('RB: beautifulP17.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: grazehappily -- detdogs -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: lions -- aimlessly -- mapping_weignt=', 1)
# ('PO: hunt -- hunt -- mapping_weignt=', 1)
# ('PO: deer -- deer -- mapping_weignt=', 1)
# ('PO: angry -- angry -- mapping_weignt=', 1)
# ('PO: roar -- slow -- mapping_weignt=', 1)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: jump -- jump -- mapping_weignt=', 1)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: know -- fat -- mapping_weignt=', 0.9658841088275075)
# ('PO: fast -- angry -- mapping_weignt=', 0.9794424918294858)
# ('PO: bulky -- think -- mapping_weignt=', 1)
# ('PO: stalk -- hiss -- mapping_weignt=', 1)
# ('PO: male -- wobble -- mapping_weignt=', 1)
# ('PO: in -- in -- mapping_weignt=', 1)
# ('PO: anger -- anger -- mapping_weignt=', 1)
# ('PO: majestic -- majestic -- mapping_weignt=', 1)
# ('PO: into -- into -- mapping_weignt=', 1)
# ('PO: darkness -- darkness -- mapping_weignt=', 1)
# ('PO: quickly -- growl -- mapping_weignt=', 1)
# ('PO: run -- from -- mapping_weignt=', 1)
# ('PO: timid -- timid -- mapping_weignt=', 1)
# ('PO: beautiful -- beautiful -- mapping_weignt=', 1)
# ('PO: graze -- graze -- mapping_weignt=', 1)
# ('PO: happily -- dogs -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 100
# retrieval successful
#
#
# Mappings:
#
# ('P: P00 -- P00 -- mapping_weight=', 0.4983515998782604)
# ('P: P01 -- P21 -- mapping_weight=', 0.9370005562293511)
# ('P: P02 -- P02 -- mapping_weight=', 0.3400126868500247)
# ('P: P03.1 -- P03.1 -- mapping_weight=', 0.9156968694296097)
# ('P: P03 -- P03 -- mapping_weight=', 1)
# ('P: P04.1 -- P34.1 -- mapping_weight=', 0.7257368682710755)
# ('P: P04 -- P17 -- mapping_weight=', 0.748668763363731)
# ('P: P05.1 -- P17.1 -- mapping_weight=', 0.3283432386674977)
# ('P: P05.2 -- P05.2 -- mapping_weight=', 0.11647350046997337)
# ('P: P05 -- P05 -- mapping_weight=', 0.7211051035018983)
# ('P: P06.1 -- P15.2 -- mapping_weight=', 0.9777095626988066)
# ('P: P06.2 -- NONE -- mapping_weight=', 0.0)
# ('P: P06 -- P06 -- mapping_weight=', 0.8884393971839831)
# ('P: P07.1 -- P24.1 -- mapping_weight=', 0.769762517544102)
# ('P: P07 -- P07 -- mapping_weight=', 0.7246052703329365)
# ('RB: detdogs -- detdogs -- mapping_weight=', 1)
# ('RB: chasecats -- chasecats -- mapping_weight=', 0.7116299112942261)
# ('RB: hungrydogs -- hungrydogs -- mapping_weight=', 1)
# ('RB: barkobj -- majesticeagles -- mapping_weight=', 0.7415369369223981)
# ('RB: detdogs -- detdogs -- mapping_weight=', 1)
# ('RB: growlobj -- detsnakes -- mapping_weight=', 1)
# ('RB: bigdogs -- bigdogs -- mapping_weight=', 0.47900046092002846)
# ('RB: bitecats -- bitecats -- mapping_weight=', 0.449115765402589)
# ('RB: detdogs -- detdogs -- mapping_weight=', 1)
# ('RB: thinkP03.1 -- crawlP26.2 -- mapping_weight=', 1)
# ('RB: smallcats -- detlions -- mapping_weight=', 0.8851962614078694)
# ('RB: bigdogs -- bigdogs -- mapping_weight=', 0.6641932078486426)
# ('RB: biteP04.1 -- beautifulP17.1 -- mapping_weight=', 1)
# ('RB: hungrydogs -- hungrydogs -- mapping_weight=', 0.621723091712013)
# ('RB: atstrangers -- biglions -- mapping_weight=', 0.9218508371801477)
# ('RB: angryP05.1 -- slowlyP26.1 -- mapping_weight=', 1)
# ('RB: growlP05.2 -- growlP05.2 -- mapping_weight=', 0.3065908435260544)
# ('RB: fromwater -- inanger -- mapping_weight=', 0.6537318450820928)
# ('RB: awayP06.1 -- awayP06.1 -- mapping_weight=', 1)
# ('RB: detkitten -- detkitten -- mapping_weight=', 1)
# ('RB: stayP06.2 -- stayP06.2 -- mapping_weight=', 1)
# ('RB: fluffycats -- fluffycats -- mapping_weight=', 0.547585887743809)
# ('RB: cuteP07.1 -- catchP24.1 -- mapping_weight=', 1)
# ('RB: purrsoftly -- huntdeer -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: dogs -- rats -- mapping_weignt=', 1)
# ('PO: chase -- think -- mapping_weignt=', 1)
# ('PO: cats -- deer -- mapping_weignt=', 1)
# ('PO: hungry -- slowly -- mapping_weignt=', 1)
# ('PO: bark -- bark -- mapping_weignt=', 1)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- growl -- mapping_weignt=', 1)
# ('PO: big -- big -- mapping_weignt=', 1)
# ('PO: bite -- hunt -- mapping_weignt=', 1)
# ('PO: think -- think -- mapping_weignt=', 1)
# ('PO: small -- in -- mapping_weignt=', 1)
# ('PO: at -- at -- mapping_weignt=', 1)
# ('PO: strangers -- traps -- mapping_weignt=', 1)
# ('PO: angry -- angry -- mapping_weignt=', 0.9090665993129934)
# ('PO: from -- from -- mapping_weignt=', 1)
# ('PO: water -- water -- mapping_weignt=', 1)
# ('PO: away -- slither -- mapping_weignt=', 1)
# ('PO: kitten -- kitten -- mapping_weignt=', 1)
# ('PO: stay -- stay -- mapping_weignt=', 1)
# ('PO: fluffy -- roar -- mapping_weignt=', 1)
# ('PO: cute -- male -- mapping_weignt=', 1)
# ('PO: purr -- angry -- mapping_weignt=', 0.9588120979939195)
# ('PO: softly -- worms -- mapping_weignt=', 1)

# %%
# Out:
# (0.6679857601499979,
#  0.6679857601499979,
#  0.6679857601499979,
#  0.07160053792025357)

# %%
# perform rowwise normalisation on mapping_adj
prop_names = [myP.name for myP in network.memory.Ps]
vis_mappings(mapping_mat=mapping_adj,prop_names=prop_names)
error_val = mapping_error(mapping_mat=mapping_adj)
print(error_val)
# Out:
# 0.12030975965751266

# %%
baseline_mapping = np.ones((mapping_adj.shape))
baseline_mapping[:,:] = 1.0/baseline_mapping.shape[0]
print get_metrics(baseline_mapping)
# Out:
# (0.049999999999999836, 0.049999999999999906, 0.04999999999999987)

# %%
fscores
# Out:
# [0.5,
#  0.75,
#  0.7777777777777778,
#  0.7,
#  0.6,
#  0.5625,
#  0.5882352941176471,
#  0.5555555555555556,
#  0.5714285714285714,
#  0.5179512483241657,
#  0.5241478908836357,
#  0.5695529094274228,
#  0.5979101227070515,
#  0.621562468430166,
#  0.6297797209180609,
#  0.6848226947844288,
#  0.6848226947844288,
#  0.7328969804514422,
#  0.7328969804514422,
#  0.7481144917095381,
#  0.738401422032726,
#  0.7547272779659678,
#  0.7564009392325537,
#  0.7626470689958216,
#  0.7626470689958216,
#  0.7564009392325537,
#  0.7564009392325537,
#  0.7466212943554731,
#  0.7511760578259955,
#  0.7465320712848754,
#  0.7465320712848754,
#  0.7425904516753739,
#  0.7260776338090429,
#  0.7260776338090429,
#  0.7253587260599662,
#  0.7250468358147429,
#  0.7336396609010393,
#  0.7314490563503713,
#  0.724190922738219,
#  0.7299925236614603,
#  0.7297510082782799,
#  0.7305920840219517,
#  0.7305920840219517,
#  0.7321666608661257,
#  0.7375063299883514,
#  0.7371679780394603,
#  0.7556006401424957,
#  0.7547168956853961,
#  0.7505221044635583,
#  0.7480305124352409,
#  0.7595353346406142,
#  0.7535964568040979,
#  0.7538467829077529,
#  0.718440122643325,
#  0.718440122643325,
#  0.718440122643325,
#  0.7117978407706842,
#  0.7112643536429508,
#  0.7091514961152544,
#  0.7112955169064482,
#  0.7173885444358222,
#  0.7162175695912627,
#  0.7322163050190559,
#  0.7327613862863063,
#  0.7321885502297253,
#  0.7321885502297253,
#  0.7327502348508524,
#  0.7299828985891859,
#  0.7172311648122162,
#  0.7166789695860254,
#  0.7166789695860254,
#  0.7175791024809344,
#  0.7344700113402517,
#  0.7348293564730417,
#  0.7346461248773842,
#  0.734643840933127,
#  0.7661026786849898,
#  0.761868679365645,
#  0.7616608844602355,
#  0.7580167540411249,
#  0.7512586926284519,
#  0.7512586926284519,
#  0.7303414812394027,
#  0.7120221877072516,
#  0.725454499984155,
#  0.7246667455322047,
#  0.715143367338019,
#  0.7142047641280895,
#  0.7108723318973053,
#  0.7108497477679263,
#  0.7079770129505789,
#  0.7077514170524092,
#  0.7078674960527829,
#  0.7078674960527829,
#  0.7078674960527829,
#  0.7068878065647778,
#  0.7009756967154731,
#  0.7011507401446516,
#  0.6969712648995038,
#  0.7001788736672568]

# %%
get_metrics(mapping_mat = mapping_adj)

# %% [markdown]
# # Trials
# ## The kinds of tests that have been done and their results :
#
# 1. Keeping the object hanging (no predicate for object) means the RB is not created for the corresponding object. Weird.
#
# 1.1 Making the predicate a one-hot semantic perhaps? - Does not work
#
# 1.2 Making the predicate an empty semantic? - Does not work
#
# 1.3 Making the predicate a one-hot semantic that is orthogonal to other vectors? still noisy
#
# 2. Keeping the predicate hanging (no object for predicate)
#
#
# 3. Making the words 1 hot representations of their lexical properties, so here subject nouns, object nouns have a 1 hot rep, verbs, complemnetizer verbs, adjectives - Does MUCH BETTER. Promising results, but why are the mappings not perfect still?
#
# 3.1 Increase/decrease eta - nope - only makes existing connections stronger/weaker
#
# 3.2 gamma/delta/Hebbbias - (currently 0.3, .1, .5)
#
# 3.3 Don't ignore object semantics, and keep asDORA True - works better than 3.0
#
# 3.4 Try changing the predicate to the noun and keep the object empty - worked fine
#
# 4. Added loss metric. Now retry for all previous analysis - 100 runs
#
# 4.1 with one_to_one=True and max_norm=False, asDORA = True, ignore_object_sem = False, RMSE = 0.09
#
# 4.2 with one_to_one=True and max_norm=True, asDORA = True, ignore_objetct_sem=False, RMSE = 0.05 (def looks better)
#
# 4.3 try to use WordGCN and RMSE = .14
#
# 4.4 baseline_mapping RMSE = 0.103 (better than wordGCN :O )
#
# 4.5 setting embedding dimension = 5, and testing for simple word2vec model, RMSE = 0.12 (still worse than baseline)
#
# 5. Understanding object/predicate semantic usage :
#
# 5.3 strategic mapping has to be True for asDORA == False ( see do_mapping() )
#
# 5.4 Try with new semantic update - previous update was non linear max norm update. New update uses only link weight * parent act - RMSE =
#
# 5.5 Try with new semantic update - added one hot semantic to empty object to distinguish it from other semantics, made sure ignore_object_semantics does not do what it should in the update_semantic code.
# RMSE = 0.098
#
# 5.6 Try with making predicate empty rather than object, RMSE = 0.108 :/

# %% [markdown]
# ## Firing order similarity analysis :
#
# To make mapping more efficient, we have to consider firing order similarity in the mix. To make things easy, we have the firing order of the propositions in the driver. This is given by the ordering of the RBs themselves.
#
# To downweight/upweight the existing mapping connections, we need to consider the following :
#
# 5.1 We consider mappings in RBs and above. Therefore for every RB in the driver, we take a look at the POs that are connected to it in the driver, and the RB it maps to in the recipient, and its POs in the Recipient.
#
# 5.2 The mapping connection between RBs is upweighted if the indices of its POs match. Ex - RB1 maps to RB2 with weight w. PO11 and PO12 are the POs connected to RB1, and PO21 and PO22 are the POs connected to RB2. index(PO11), index(PO12), index(PO21), index(PO22) indicate where they appear in the RBs. Spearman Rank correlation between them should point to how similar they are.
#
# ## Stuff to do :
#
# 1. First, collect all mapping hypotheses in one place. This consists of all connections from Driver propositions to all recipient tokens of same type.
#
# 1.1 Don't break it now, but the Luce's choice algorithm is a bit weird. Gotta see why they use it. - instead of random threshold to retrieve analogs, use a fixed threshold = 0.1 currently
#
# 1.2 with threshold = 0.1, biasing proposition length as well, RMSE = 0.11 - looks bad. Got to find out a way to include RB firing order instead.
#
# 1.3 Make sure P in parent is mapped to P in parent only.
#
# 1.4 After taking out the one to one mapping constraint, mappings improve. - RMSE = 0.0853, set parent_bias = 0.5!
#
# 1.5 setting parent_bias = 0.1 , 0.088 (not significant enough imo)
#
# 1.6 see how firing order similarity is affecting mapping coeff. Currently, mapping is in SSL, guided by a simple Hebbian learning rule that has coactivation as its basis. added correlations between activations to update_hyp. Correlations + one_to_one == True, RMSE = 0.067, one_to_one == False, RMSE = 0.077 (higher rmse :O )
#
# 1.7 Something to test out - parent and child modes need to be updated based on presence of parentRBs, not activations alons, nah?
#
# 1.8 Run with larger prop number
#
# 1.9 Non recursive correlational mapping - 0.111
#
# 2.0 Firing by POs, mapping not reset after each run (god knows why that was being done in the first place)
#
# 2.1 Why does retrieval by bias_analog work so strangely?
#
# ## Results -
#
# 1.1 Collect RMSE over time, and plot the evolution
# 1.2 Comparison across word embedding strategies used
# 1.3 Record RB firing for proposition 0 in Ding stimuli style
