# %%
import random
import buildNetwork
import basicRunDORA
import pdb
import numpy as np
import seaborn as sns
NUM_ANALOGS = 4
N_COMPONENTS = 10
PER_ANALOG = 5
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
parameters = {'asDORA': True, 'gamma': 0.3,
              'delta': 0.05, 'eta': 0.9,
              'HebbBias': 0.5,'bias_retrieval_analogs': True, 'use_relative_act': True,
              #'run_order': ['cdr', 'selectTokens', 'r', 'wp', 'm', 'p', 's', 'f', 'c'],
              'run_order': ['cdr', 'selectTokens', 'r', 'm','c'],
              'run_cyles': 500, 'write_on_iteration': 100, 'firingOrderRule': 'in_order',
              'dim_list':[],
              'strategic_mapping': True, 'ignore_object_semantics': False,
              'ignore_memory_semantics': True, 'mag_decimal_precision': 0,
              'exemplar_memory': False, 'recent_analog_bias': True,
              'lateral_input_level': 1, 'screen_width': 1200, 'screen_height': 700,
              'doGUI': False, 'testing': True, 'GUI_update_rate': 50, 'starting_iteration': 0,
              'tokenize': False, 'ho_sem_act_flow': 0, 'remove_uncompressed': False, 'remove_compressed': False,
              'num_choose':10,'one_to_one':True,'max_norm':True, 'filename':'karthikeya/test_sim_custom-5-empty_pred.py',
             'len_regularisation':1, 'count_by_RBs':True, 'parent_bias':0.1, 'order_activation_bias':0.5}

# %%
def init_network(parameters):
    reload(buildNetwork)
    reload(basicRunDORA)
    fileName = parameters['filename']
    f = open(fileName, 'r')
    simType = ''
    d = {'simType': simType}
    f.seek(0)
    exec (f.readline())
    if simType == 'sym_file':
        symstring = ''
        for line in f:
            symstring += line
        exec(symstring)
    # initialise memory
    memory = buildNetwork.initializeMemorySet()
    # interpret sym file
    mysym = buildNetwork.interpretSymfile(symProps)
    # build the network
    memory = basicRunDORA.dataTypes.memorySet()
    memory = buildNetwork.buildTheNetwork(mysym[0], memory)
    network = basicRunDORA.runDORA(memory, parameters)
    memory = basicRunDORA.update_memory_with_levels(memory)
    # run cycles
    # initialise mapping adjacency matrix:
    mapping_adj = np.zeros((len(network.memory.Ps), len(network.memory.Ps)))
    return [network, memory, mapping_adj]

# %%
def vis_mappings(mapping_mat, prop_names):
    sns_heatmap = sns.heatmap(mapping_mat, linewidth=0.5,xticklabels=prop_names, yticklabels=prop_names)
    fig = sns_heatmap.get_figure()
    return

# %%
def mapping_error(mapping_mat):
    # assuming an even split - NUM_ANALOGS * PER_ANALOG = number of analogs, number of propositions per analog
    # the mapping matrix is ordered by propositions, therefore every n%PER_ANALOG should be mapped together.
    # the mapping_mat is L1 normalised, and so the target matrix should contain values = 1.0/(NUM_ANALOGS - 1)
    target_mat = np.zeros(mapping_mat.shape)
    per_analog = mapping_mat.shape[0]/NUM_ANALOGS
    for row in range(target_mat.shape[0]):
        target_indices = [(idx*per_analog + row%per_analog) for idx in range(NUM_ANALOGS)] # fill the target mapping indices
        target_indices.pop(target_indices.index(row))
        target_mat[row,target_indices] = 1.0/(NUM_ANALOGS - 1)
    error_mat = (mapping_mat - target_mat)**2
    error_val = np.sqrt(np.mean(error_mat))
    return error_val

# %%
# networ, memory, mapping_adj = init_network()
for cycle in range(parameters['run_cyles']):
    print('\n\n************************* Cycle: ' + str(cycle+1))

    # clear driver and recipient
    network.memory = basicRunDORA.clearDriverSet(network.memory)
    network.memory = basicRunDORA.clearRecipientSet(network.memory)

    # put the randomly chosen proposition in the driver
    proposition = random.sample(network.memory.Ps,k=parameters['num_choose']) # currently three propositions
    if parameters['num_choose'] > 1:
        proposition_num = []
        for p in proposition:
            proposition_num.append(network.memory.Ps.index(p))
    else:
        proposition_num = network.memory.Ps.index(proposition)

    if parameters['num_choose'] > 1:
        for p_num in proposition_num:
            network.memory = basicRunDORA.add_tokens_to_set(network.memory, p_num, 'P', 'driver')
    else:
        network.memory = basicRunDORA.add_tokens_to_set(network.memory, proposition_num, 'P', 'driver')



    # make sure the driver and the recipient are set
    network.memory = basicRunDORA.findDriverRecipient(network.memory)
    network.do_map()

    # display ALL mappings
    #pdb.set_trace()
    for myP in network.memory.driver.Ps:
        for mapping in myP.mappingConnections:
            map_weight = mapping.weight
            if map_weight > 0:
                map_unit = mapping.recipientToken
                if mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)] < 0.1:
                    mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)] = map_weight
                else:
                    mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)] = (map_weight + 
                        mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)])/2.0 # DIRTY SOLUTION FOR NOW
            #print str(network.memory.Ps.index(myP)) + str(' -- ') + str(network.memory.Ps.index(map_unit)) + str(' : ') + str(map_weight)


    # display mappings
    print('\n\nMappings:\n')
    basicRunDORA.DORA_GUI.term_map_display(network.memory, only_Ps=True, only_max=False)

# %%
network, memory, mapping_adj = init_network(parameters)
for cycle in range(parameters['run_cyles']):
    print('\n\n************************* Cycle: ' + str(cycle+1))
    #pdb.set_trace()
    # clear driver and recipient
    network.memory = basicRunDORA.clearDriverSet(network.memory)
    network.memory = basicRunDORA.clearRecipientSet(network.memory)
    # choose random analog from memory
    analog = random.choice(network.memory.analogs) # currently only one analog
    # choose random propositions from memory

    # put the analog in the driver
    analog_num = network.memory.analogs.index(analog)
    network.memory = basicRunDORA.add_tokens_to_set(network.memory, analog_num, 'analog', 'driver')
    # retrieve analogs similar to one in the driver from LTM
    network.memory = basicRunDORA.findDriverRecipient(network.memory)
    network.do_retrieval()
    network.memory = basicRunDORA.findDriverRecipient(network.memory)
    
    #print('In driver : ' + network.memory.driver.Ps[0].name[1])
    #if len(network.memory.recipient.Ps) > 0:
    #    print('In recipient : ' + network.memory.recipient.Ps[0].name[1])
    #    if network.memory.recipient.Ps[0].name[1] == '3':
    #        network.do_map()
    #        print('\n\nMappings:\n')
    #        basicRunDORA.DORA_GUI.term_map_display(network.memory, only_Ps=True, only_max=False)

    if len(network.memory.recipient.Ps) > 0: 
        print 'retrieval successful'
        # map the analogs in driver and recipient
        network.do_map()
    # display ALL mappings
    # display mappings
    print('\n\nMappings:\n')
    basicRunDORA.DORA_GUI.term_map_display(network.memory, only_Ps=False, only_max=False)
    # store all mappings : 
    for myP in network.memory.driver.Ps:
        for mapping in myP.mappingConnections:
            map_weight = mapping.weight
            map_unit = mapping.recipientToken
            mapping_adj[network.memory.Ps.index(myP), network.memory.Ps.index(map_unit)] += map_weight
    # clear mappings
    #network.memory = basicRunDORA.reset_mappings(network.memory)

    
# normalise mappings
for ind in range(mapping_adj.shape[0]):
    if sum(mapping_adj[ind,:]) > 0:
        mapping_adj[ind,:] = mapping_adj[ind,:]/sum(mapping_adj[ind,:])
# Out:
# ************************* Cycle: 1
#
#
# Mappings:
#
# ('P: P20 -- NONE -- mapping_weight=', 0.0)
# ('P: P21 -- NONE -- mapping_weight=', 0.0)
# ('P: P22 -- NONE -- mapping_weight=', 0.0)
# ('P: P23.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P23 -- NONE -- mapping_weight=', 0.0)
# ('P: P24.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P24 -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: eatworms -- NONE -- mapping_weight=', 0.0)
# ('RB: majesticeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: glideobj -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: flyobj -- NONE -- mapping_weight=', 0.0)
# ('RB: earlyeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: spotworms -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: sayP23.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: easyworms -- NONE -- mapping_weight=', 0.0)
# ('RB: wiseeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: catchP24.1 -- NONE -- mapping_weight=', 0.0)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: eagles -- NONE -- mapping_weignt=', 0.0)
# ('PO: eat -- NONE -- mapping_weignt=', 0.0)
# ('PO: worms -- NONE -- mapping_weignt=', 0.0)
# ('PO: majestic -- NONE -- mapping_weignt=', 0.0)
# ('PO: glide -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: fly -- NONE -- mapping_weignt=', 0.0)
# ('PO: early -- NONE -- mapping_weignt=', 0.0)
# ('PO: spot -- NONE -- mapping_weignt=', 0.0)
# ('PO: say -- NONE -- mapping_weignt=', 0.0)
# ('PO: easy -- NONE -- mapping_weignt=', 0.0)
# ('PO: wise -- NONE -- mapping_weignt=', 0.0)
# ('PO: catch -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 2
#
#
# Mappings:
#
# ('P: P30 -- NONE -- mapping_weight=', 0.0)
# ('P: P31 -- NONE -- mapping_weight=', 0.0)
# ('P: P32 -- NONE -- mapping_weight=', 0.0)
# ('P: P33.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P33 -- NONE -- mapping_weight=', 0.0)
# ('P: P34.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P34 -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: angrysnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: hissobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: slitherobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP33.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: juicyrats -- NONE -- mapping_weight=', 0.0)
# ('RB: cunningsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: loveP34.1 -- NONE -- mapping_weight=', 0.0)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: snakes -- NONE -- mapping_weignt=', 0.0)
# ('PO: eat -- NONE -- mapping_weignt=', 0.0)
# ('PO: rats -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: hiss -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: slither -- NONE -- mapping_weignt=', 0.0)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: juicy -- NONE -- mapping_weignt=', 0.0)
# ('PO: cunning -- NONE -- mapping_weignt=', 0.0)
# ('PO: love -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 3
#
#
# Mappings:
#
# ('P: P20 -- NONE -- mapping_weight=', 0.0)
# ('P: P21 -- NONE -- mapping_weight=', 0.0)
# ('P: P22 -- NONE -- mapping_weight=', 0.0)
# ('P: P23.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P23 -- NONE -- mapping_weight=', 0.0)
# ('P: P24.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P24 -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: eatworms -- NONE -- mapping_weight=', 0.0)
# ('RB: majesticeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: glideobj -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: flyobj -- NONE -- mapping_weight=', 0.0)
# ('RB: earlyeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: spotworms -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: sayP23.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: easyworms -- NONE -- mapping_weight=', 0.0)
# ('RB: wiseeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: catchP24.1 -- NONE -- mapping_weight=', 0.0)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: eagles -- NONE -- mapping_weignt=', 0.0)
# ('PO: eat -- NONE -- mapping_weignt=', 0.0)
# ('PO: worms -- NONE -- mapping_weignt=', 0.0)
# ('PO: majestic -- NONE -- mapping_weignt=', 0.0)
# ('PO: glide -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: fly -- NONE -- mapping_weignt=', 0.0)
# ('PO: early -- NONE -- mapping_weignt=', 0.0)
# ('PO: spot -- NONE -- mapping_weignt=', 0.0)
# ('PO: say -- NONE -- mapping_weignt=', 0.0)
# ('PO: easy -- NONE -- mapping_weignt=', 0.0)
# ('PO: wise -- NONE -- mapping_weignt=', 0.0)
# ('PO: catch -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 4
#
#
# Mappings:
#
# ('P: P10 -- NONE -- mapping_weight=', 0.0)
# ('P: P11 -- NONE -- mapping_weight=', 0.0)
# ('P: P12 -- NONE -- mapping_weight=', 0.0)
# ('P: P13.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P13 -- NONE -- mapping_weight=', 0.0)
# ('P: P14.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P14 -- NONE -- mapping_weight=', 0.0)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: angrylions -- NONE -- mapping_weight=', 0.0)
# ('RB: roarobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: jumpobj -- NONE -- mapping_weight=', 0.0)
# ('RB: biglions -- NONE -- mapping_weight=', 0.0)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: knowP13.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: fastdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: bulkylions -- NONE -- mapping_weight=', 0.0)
# ('RB: stalkP14.1 -- NONE -- mapping_weight=', 0.0)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: lions -- NONE -- mapping_weignt=', 0.0)
# ('PO: hunt -- NONE -- mapping_weignt=', 0.0)
# ('PO: deer -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: roar -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: jump -- NONE -- mapping_weignt=', 0.0)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: know -- NONE -- mapping_weignt=', 0.0)
# ('PO: fast -- NONE -- mapping_weignt=', 0.0)
# ('PO: bulky -- NONE -- mapping_weignt=', 0.0)
# ('PO: stalk -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 5
#
#
# Mappings:
#
# ('P: P30 -- NONE -- mapping_weight=', 0.0)
# ('P: P31 -- NONE -- mapping_weight=', 0.0)
# ('P: P32 -- NONE -- mapping_weight=', 0.0)
# ('P: P33.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P33 -- NONE -- mapping_weight=', 0.0)
# ('P: P34.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P34 -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: angrysnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: hissobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: slitherobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP33.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: juicyrats -- NONE -- mapping_weight=', 0.0)
# ('RB: cunningsnakes -- NONE -- mapping_weight=', 0.0)
# ('RB: loveP34.1 -- NONE -- mapping_weight=', 0.0)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: snakes -- NONE -- mapping_weignt=', 0.0)
# ('PO: eat -- NONE -- mapping_weignt=', 0.0)
# ('PO: rats -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: hiss -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: slither -- NONE -- mapping_weignt=', 0.0)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: juicy -- NONE -- mapping_weignt=', 0.0)
# ('PO: cunning -- NONE -- mapping_weignt=', 0.0)
# ('PO: love -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 6
#
#
# Mappings:
#
# ('P: P10 -- NONE -- mapping_weight=', 0.0)
# ('P: P11 -- NONE -- mapping_weight=', 0.0)
# ('P: P12 -- NONE -- mapping_weight=', 0.0)
# ('P: P13.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P13 -- NONE -- mapping_weight=', 0.0)
# ('P: P14.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P14 -- NONE -- mapping_weight=', 0.0)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: angrylions -- NONE -- mapping_weight=', 0.0)
# ('RB: roarobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: jumpobj -- NONE -- mapping_weight=', 0.0)
# ('RB: biglions -- NONE -- mapping_weight=', 0.0)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: detlions -- NONE -- mapping_weight=', 0.0)
# ('RB: knowP13.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: fastdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: bulkylions -- NONE -- mapping_weight=', 0.0)
# ('RB: stalkP14.1 -- NONE -- mapping_weight=', 0.0)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: lions -- NONE -- mapping_weignt=', 0.0)
# ('PO: hunt -- NONE -- mapping_weignt=', 0.0)
# ('PO: deer -- NONE -- mapping_weignt=', 0.0)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: roar -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: jump -- NONE -- mapping_weignt=', 0.0)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: know -- NONE -- mapping_weignt=', 0.0)
# ('PO: fast -- NONE -- mapping_weignt=', 0.0)
# ('PO: bulky -- NONE -- mapping_weignt=', 0.0)
# ('PO: stalk -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 7
# Mappings:
#
# ('P: P20 -- NONE -- mapping_weight=', 0.0)
# ('P: P21 -- NONE -- mapping_weight=', 0.0)
# ('P: P22 -- NONE -- mapping_weight=', 0.0)
# ('P: P23.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P23 -- NONE -- mapping_weight=', 0.0)
# ('P: P24.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P24 -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: eatworms -- NONE -- mapping_weight=', 0.0)
# ('RB: majesticeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: glideobj -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: flyobj -- NONE -- mapping_weight=', 0.0)
# ('RB: earlyeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: spotworms -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: sayP23.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: easyworms -- NONE -- mapping_weight=', 0.0)
# ('RB: wiseeagles -- NONE -- mapping_weight=', 0.0)
# ('RB: catchP24.1 -- NONE -- mapping_weight=', 0.0)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: eagles -- NONE -- mapping_weignt=', 0.0)
# ('PO: eat -- NONE -- mapping_weignt=', 0.0)
# ('PO: worms -- NONE -- mapping_weignt=', 0.0)
# ('PO: majestic -- NONE -- mapping_weignt=', 0.0)
# ('PO: glide -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: fly -- NONE -- mapping_weignt=', 0.0)
# ('PO: early -- NONE -- mapping_weignt=', 0.0)
# ('PO: spot -- NONE -- mapping_weignt=', 0.0)
# ('PO: say -- NONE -- mapping_weignt=', 0.0)
# ('PO: easy -- NONE -- mapping_weignt=', 0.0)
# ('PO: wise -- NONE -- mapping_weignt=', 0.0)
# ('PO: catch -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 8
# retrieval successful
#
#
# Mappings:
#
# ('P: P10 -- P22 -- mapping_weight=', 0.8347612039966467)
# ('P: P11 -- P23.1 -- mapping_weight=', 0.24397307656887818)
# ('P: P12 -- P20 -- mapping_weight=', 0.8524647038479141)
# ('P: P13.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P13 -- P23 -- mapping_weight=', 1)
# ('P: P14.1 -- P24.1 -- mapping_weight=', 1)
# ('P: P14 -- P24 -- mapping_weight=', 1)
# ('RB: detlions -- deteagles -- mapping_weight=', 0.059705863831689035)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: angrylions -- NONE -- mapping_weight=', 0.0)
# ('RB: roarobj -- eatworms -- mapping_weight=', 0.008001045868037038)
# ('RB: detdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: jumpobj -- wiseeagles -- mapping_weight=', 0.4573972234793727)
# ('RB: biglions -- NONE -- mapping_weight=', 0.0)
# ('RB: huntdeer -- earlyeagles -- mapping_weight=', 0.0003552032209075096)
# ('RB: detlions -- deteagles -- mapping_weight=', 0.22244612210479103)
# ('RB: knowP13.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: fastdeer -- easyworms -- mapping_weight=', 0.5857769293527737)
# ('RB: bulkylions -- majesticeagles -- mapping_weight=', 0.7059696027879343)
# ('RB: stalkP14.1 -- catchP24.1 -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: lions -- eagles -- mapping_weignt=', 0.5432880684043112)
# ('PO: hunt -- early -- mapping_weignt=', 0.44150426979053137)
# ('PO: deer -- worms -- mapping_weignt=', 0.4111541403686316)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: roar -- eat -- mapping_weignt=', 0.4444297642657293)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: jump -- wise -- mapping_weignt=', 1)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: know -- say -- mapping_weignt=', 1)
# ('PO: fast -- easy -- mapping_weignt=', 1)
# ('PO: bulky -- majestic -- mapping_weignt=', 1)
# ('PO: stalk -- catch -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 9
#
#
# Mappings:
#
# ('P: P20 -- P20 -- mapping_weight=', 0.8524647038479141)
# ('P: P21 -- NONE -- mapping_weight=', 0.0)
# ('P: P22 -- P22 -- mapping_weight=', 0.8347612039966467)
# ('P: P23.1 -- P23.1 -- mapping_weight=', 0.24397307656887818)
# ('P: P23 -- P23 -- mapping_weight=', 1)
# ('P: P24.1 -- P24.1 -- mapping_weight=', 1)
# ('P: P24 -- P24 -- mapping_weight=', 1)
# ('RB: deteagles -- NONE -- mapping_weight=', 0.0)
# ('RB: eatworms -- eatworms -- mapping_weight=', 0.008001045868037038)
# ('RB: majesticeagles -- majesticeagles -- mapping_weight=', 0.7059696027879343)
# ('RB: glideobj -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- deteagles -- mapping_weight=', 0.059705863831689035)
# ('RB: flyobj -- NONE -- mapping_weight=', 0.0)
# ('RB: earlyeagles -- earlyeagles -- mapping_weight=', 0.0003552032209075096)
# ('RB: spotworms -- NONE -- mapping_weight=', 0.0)
# ('RB: deteagles -- deteagles -- mapping_weight=', 0.22244612210479103)
# ('RB: sayP23.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: easyworms -- easyworms -- mapping_weight=', 0.5857769293527737)
# ('RB: wiseeagles -- wiseeagles -- mapping_weight=', 0.4573972234793727)
# ('RB: catchP24.1 -- catchP24.1 -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 1)
# ('PO: eagles -- eagles -- mapping_weignt=', 0.5432880684043112)
# ('PO: eat -- eat -- mapping_weignt=', 0.4444297642657293)
# ('PO: worms -- worms -- mapping_weignt=', 0.4111541403686316)
# ('PO: majestic -- majestic -- mapping_weignt=', 1)
# ('PO: glide -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: fly -- NONE -- mapping_weignt=', 0.0)
# ('PO: early -- early -- mapping_weignt=', 0.44150426979053137)
# ('PO: spot -- NONE -- mapping_weignt=', 0.0)
# ('PO: say -- say -- mapping_weignt=', 1)
# ('PO: easy -- easy -- mapping_weignt=', 1)
# ('PO: wise -- wise -- mapping_weignt=', 1)
# ('PO: catch -- catch -- mapping_weignt=', 1)
#
#
# ************************* Cycle: 10
#
#
# Mappings:
#
# ('P: P00 -- NONE -- mapping_weight=', 0.0)
# ('P: P01 -- NONE -- mapping_weight=', 0.0)
# ('P: P02 -- NONE -- mapping_weight=', 0.0)
# ('P: P03.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P03 -- NONE -- mapping_weight=', 0.0)
# ('P: P04.1 -- NONE -- mapping_weight=', 0.0)
# ('P: P04 -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: bitecats -- NONE -- mapping_weight=', 0.0)
# ('RB: hungrydogs -- NONE -- mapping_weight=', 0.0)
# ('RB: barkobj -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: growlobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: bitecats -- NONE -- mapping_weight=', 0.0)
# ('RB: detdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: thinkP03.1 -- NONE -- mapping_weight=', 0.0)
# ('RB: smallcats -- NONE -- mapping_weight=', 0.0)
# ('RB: bigdogs -- NONE -- mapping_weight=', 0.0)
# ('RB: biteP04.1 -- NONE -- mapping_weight=', 0.0)
# ('PO: det -- NONE -- mapping_weignt=', 0.0)
# ('PO: dogs -- NONE -- mapping_weignt=', 0.0)
# ('PO: bite -- NONE -- mapping_weignt=', 0.0)
# ('PO: cats -- NONE -- mapping_weignt=', 0.0)
# ('PO: hungry -- NONE -- mapping_weignt=', 0.0)
# ('PO: bark -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: growl -- NONE -- mapping_weignt=', 0.0)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: think -- NONE -- mapping_weignt=', 0.0)
# ('PO: small -- NONE -- mapping_weignt=', 0.0)
#
#
# ************************* Cycle: 11
# retrieval successful
#
#
# Mappings:
#
# ('P: P10 -- P20 -- mapping_weight=', 0.8482795346581362)
# ('P: P11 -- P23.1 -- mapping_weight=', 0.1557077222114086)
# ('P: P12 -- P22 -- mapping_weight=', 0.8494871718259247)
# ('P: P13.1 -- P23.1 -- mapping_weight=', 0.1426804349490601)
# ('P: P13 -- P23 -- mapping_weight=', 1)
# ('P: P14.1 -- P24.1 -- mapping_weight=', 1)
# ('P: P14 -- P24 -- mapping_weight=', 0.989083843936594)
# ('RB: detlions -- deteagles -- mapping_weight=', 0.047339540087143604)
# ('RB: huntdeer -- eatworms -- mapping_weight=', 0.5007658719746381)
# ('RB: angrylions -- earlyeagles -- mapping_weight=', 0.2479206856509157)
# ('RB: roarobj -- spotworms -- mapping_weight=', 0.12892528002437773)
# ('RB: detdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: jumpobj -- wiseeagles -- mapping_weight=', 0.28558256817116456)
# ('RB: biglions -- earlyeagles -- mapping_weight=', 0.007198375733557251)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: detlions -- deteagles -- mapping_weight=', 0.24501243587880528)
# ('RB: knowP13.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: fastdeer -- easyworms -- mapping_weight=', 0.30544354167970267)
# ('RB: bulkylions -- majesticeagles -- mapping_weight=', 0.39377536021845494)
# ('RB: stalkP14.1 -- catchP24.1 -- mapping_weight=', 1)
# ('PO: det -- det -- mapping_weignt=', 0.8414733235108325)
# ('PO: lions -- eagles -- mapping_weignt=', 0.5279248321555424)
# ('PO: hunt -- eat -- mapping_weignt=', 0.020650269094172218)
# ('PO: deer -- worms -- mapping_weignt=', 0.3448896158090427)
# ('PO: angry -- spot -- mapping_weignt=', 0.08454118519365056)
# ('PO: roar -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: jump -- wise -- mapping_weignt=', 0.23471748454256053)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: know -- say -- mapping_weignt=', 1)
# ('PO: fast -- easy -- mapping_weignt=', 0.07572033358433705)
# ('PO: bulky -- majestic -- mapping_weignt=', 0.5696441110041083)
# ('PO: stalk -- catch -- mapping_weignt=', 0.6123586701782348)
#
#
# ************************* Cycle: 12
# retrieval successful
#
#
# Mappings:
#
# ('P: P30 -- P22 -- mapping_weight=', 1)
# ('P: P31 -- P23.1 -- mapping_weight=', 0.9485634982867838)
# ('P: P32 -- P20 -- mapping_weight=', 1)
# ('P: P33.1 -- P21 -- mapping_weight=', 0.36852983332688705)
# ('P: P33 -- P23 -- mapping_weight=', 1)
# ('P: P34.1 -- P24.1 -- mapping_weight=', 1)
# ('P: P34 -- P24 -- mapping_weight=', 1)
# ('RB: detsnakes -- deteagles -- mapping_weight=', 0.11086632977907594)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: angrysnakes -- easyworms -- mapping_weight=', 0.007106387989490303)
# ('RB: hissobj -- majesticeagles -- mapping_weight=', 0.04128220794742196)
# ('RB: detsnakes -- deteagles -- mapping_weight=', 0.11607972438973882)
# ('RB: slitherobj -- NONE -- mapping_weight=', 0.0)
# ('RB: bigsnakes -- eatworms -- mapping_weight=', 0.029572215593818733)
# ('RB: eatrats -- NONE -- mapping_weight=', 0.0)
# ('RB: detsnakes -- deteagles -- mapping_weight=', 0.11701660872370717)
# ('RB: thinkP33.1 -- sayP23.1 -- mapping_weight=', 1)
# ('RB: juicyrats -- earlyeagles -- mapping_weight=', 0.8712057024826573)
# ('RB: cunningsnakes -- spotworms -- mapping_weight=', 0.7216335289904595)
# ('RB: loveP34.1 -- catchP24.1 -- mapping_weight=', 0.9900000000000001)
# ('PO: det -- det -- mapping_weignt=', 0.7949463194214521)
# ('PO: snakes -- worms -- mapping_weignt=', 0.8625884081737969)
# ('PO: eat -- majestic -- mapping_weignt=', 0.0026657897003793223)
# ('PO: rats -- eagles -- mapping_weignt=', 0.5927599113049014)
# ('PO: angry -- easy -- mapping_weignt=', 0.019172246063941585)
# ('PO: hiss -- NONE -- mapping_weignt=', 0.0)
# ('PO: obj -- NONE -- mapping_weignt=', 0.0)
# ('PO: slither -- eat -- mapping_weignt=', 0.042111109343099626)
# ('PO: big -- NONE -- mapping_weignt=', 0.0)
# ('PO: think -- say -- mapping_weignt=', 1)
# ('PO: juicy -- early -- mapping_weignt=', 0.8605836998805018)
# ('PO: cunning -- spot -- mapping_weignt=', 0.8687933290348674)
# ('PO: love -- wise -- mapping_weignt=', 0.032046270393266595)
#
#
# ************************* Cycle: 13
# retrieval successful
#
#
# Mappings:
#
# ('P: P10 -- P32 -- mapping_weight=', 1)
# ('P: P11 -- P30 -- mapping_weight=', 1)
# ('P: P12 -- P22 -- mapping_weight=', 0.6855598507779596)
# ('P: P13.1 -- P33.1 -- mapping_weight=', 1)
# ('P: P13 -- P33 -- mapping_weight=', 1)
# ('P: P14.1 -- P24.1 -- mapping_weight=', 0.04654334478678103)
# ('P: P14 -- P34 -- mapping_weight=', 1)
# ('RB: detlions -- eatrats -- mapping_weight=', 0.0004822375597587148)
# ('RB: huntdeer -- detsnakes -- mapping_weight=', 0.7706299710075489)
# ('RB: angrylions -- detsnakes -- mapping_weight=', 0.39289714454394603)
# ('RB: roarobj -- detsnakes -- mapping_weight=', 0.4698800064487896)
# ('RB: detdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: jumpobj -- angrysnakes -- mapping_weight=', 0.050774394972089965)
# ('RB: biglions -- bigsnakes -- mapping_weight=', 0.5482789413188802)
# ('RB: huntdeer -- NONE -- mapping_weight=', 0.0)
# ('RB: detlions -- eatrats -- mapping_weight=', 0.001151337227120003)
# ('RB: knowP13.1 -- thinkP33.1 -- mapping_weight=', 1)
# ('RB: fastdeer -- earlyeagles -- mapping_weight=', 0.3599116525276527)
# ('RB: bulkylions -- juicyrats -- mapping_weight=', 0.5512588813814594)
# ('RB: stalkP14.1 -- loveP34.1 -- mapping_weight=', 1)
# ('PO: det -- catch -- mapping_weignt=', 0.7976275873587992)
# ('PO: lions -- rats -- mapping_weignt=', 0.9969174689130902)
# ('PO: hunt -- det -- mapping_weignt=', 0.6714223097673947)
# ('PO: deer -- eagles -- mapping_weignt=', 1)
# ('PO: angry -- NONE -- mapping_weignt=', 0.0)
# ('PO: roar -- det -- mapping_weignt=', 0.08151298644335253)
# ('PO: obj -- snakes -- mapping_weignt=', 0.7101762828134421)
# ('PO: jump -- love -- mapping_weignt=', 0.27925137992163757)
# ('PO: big -- big -- mapping_weignt=', 0.7810254425269572)
# ('PO: know -- think -- mapping_weignt=', 1)
# ('PO: fast -- early -- mapping_weignt=', 0.49715729266728553)
# ('PO: bulky -- juicy -- mapping_weignt=', 0.5909213551636404)
# ('PO: stalk -- love -- mapping_weignt=', 0.3727186489762026)
#
#
# ************************* Cycle: 14
# retrieval successful
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-0b07702d8a1c> in <module>()
#      29         print 'retrieval successful'
#      30         # map the analogs in driver and recipient
# ---> 31         network.do_map()
#      32     # display ALL mappings
#      33     # display mappings
#
# C:\Users\karkau\Documents\karthikeya\Dora\BrPong_1\workspace\basicRunDORA.py in do_map(self)
#     163                         self.time_step_activations(phase_set, self.ignore_object_semantics, self.ignore_memory_semantics)
#     164                         # 4.3.11) Update mapping hypotheses.
# --> 165                         self.memory = update_mappingHyps(self.memory, self.order_activation_bias)
#     166                         # fire the local_inhibitor if necessary.
#     167                         #pdb.set_trace()
#
# C:\Users\karkau\Documents\karthikeya\Dora\BrPong_1\workspace\basicRunDORA.py in update_mappingHyps(memory, order_activation_bias, recursive)
#    2345                 if hypothesis.driverToken.my_type == 'P' or hypothesis.driverToken.my_type == 'RB':
#    2346                     correlation_vals = get_correlations(l1=flatten(get_immediate_acts(hypothesis.driverToken)),
# -> 2347                                                           l2=flatten(get_immediate_acts(hypothesis.recipientToken)))
#    2348                     if correlation_vals != correlation_vals: # handle nans
#    2349                         correlation_vals = 0.0
#
# C:\Users\karkau\Documents\karthikeya\Dora\BrPong_1\workspace\basicRunDORA.py in get_correlations(l1, l2)
#    4231         return 0.0
#    4232     l1,l2 = np.array(l1),np.array(l2)
# -> 4233     return np.corrcoef(l1,l2)[0,1]
#    4234
#    4235 def print_hyps(memory):
#
# C:\Users\karkau\AppData\Local\Continuum\anaconda2\envs\Dora\lib\site-packages\numpy\lib\function_base.pyc in corrcoef(x, y, rowvar, bias, ddof)
#    2535     # excessive work.
#    2536     np.clip(c.real, -1, 1, out=c.real)
# -> 2537     if np.iscomplexobj(c):
#    2538         np.clip(c.imag, -1, 1, out=c.imag)
#    2539
#
# KeyboardInterrupt:

# %%
# perform rowwise normalisation on mapping_adj
prop_names = [myP.name for myP in network.memory.Ps]
vis_mappings(mapping_mat=mapping_adj,prop_names=prop_names)
error_val = mapping_error(mapping_mat=mapping_adj)
print(error_val)
# Out:
# 0.2130401094681688

# %%
baseline_mapping = np.zeros((mapping_adj.shape))
baseline_mapping[:,:] = 1.0/baseline_mapping.shape[0]
error_val = mapping_error(mapping_mat=baseline_mapping)
print(error_val)
# Out:
# 0.10309826235529031

# %%
network.memory.POs[0].mySemantics[0].weight
# Out:
# 0.3174211048946297

# %% [markdown]
# # Trials
# ## The kinds of tests that have been done and their results :
#
# 1. Keeping the object hanging (no predicate for object) means the RB is not created for the corresponding object. Weird.
#
# 1.1 Making the predicate a one-hot semantic perhaps? - Does not work
#
# 1.2 Making the predicate an empty semantic? - Does not work
#
# 1.3 Making the predicate a one-hot semantic that is orthogonal to other vectors? still noisy
#
# 2. Keeping the predicate hanging (no object for predicate)
#
#
# 3. Making the words 1 hot representations of their lexical properties, so here subject nouns, object nouns have a 1 hot rep, verbs, complemnetizer verbs, adjectives - Does MUCH BETTER. Promising results, but why are the mappings not perfect still?
#
# 3.1 Increase/decrease eta - nope - only makes existing connections stronger/weaker
#
# 3.2 gamma/delta/Hebbbias - (currently 0.3, .1, .5)
#
# 3.3 Don't ignore object semantics, and keep asDORA True - works better than 3.0
#
# 3.4 Try changing the predicate to the noun and keep the object empty - worked fine
#
# 4. Added loss metric. Now retry for all previous analysis - 100 runs
#
# 4.1 with one_to_one=True and max_norm=False, asDORA = True, ignore_object_sem = False, RMSE = 0.09
#
# 4.2 with one_to_one=True and max_norm=True, asDORA = True, ignore_objetct_sem=False, RMSE = 0.05 (def looks better)
#
# 4.3 try to use WordGCN and RMSE = .14
#
# 4.4 baseline_mapping RMSE = 0.103 (better than wordGCN :O )
#
# 4.5 setting embedding dimension = 5, and testing for simple word2vec model, RMSE = 0.12 (still worse than baseline)
#
# 5. Understanding object/predicate semantic usage :
#
# 5.3 strategic mapping has to be True for asDORA == False ( see do_mapping() )
#
# 5.4 Try with new semantic update - previous update was non linear max norm update. New update uses only link weight * parent act - RMSE =
#
# 5.5 Try with new semantic update - added one hot semantic to empty object to distinguish it from other semantics, made sure ignore_object_semantics does not do what it should in the update_semantic code.
# RMSE = 0.098
#
# 5.6 Try with making predicate empty rather than object, RMSE = 0.108 :/

# %% [markdown]
# ## Firing order similarity analysis :
#
# To make mapping more efficient, we have to consider firing order similarity in the mix. To make things easy, we have the firing order of the propositions in the driver. This is given by the ordering of the RBs themselves.
#
# To downweight/upweight the existing mapping connections, we need to consider the following :
#
# 5.1 We consider mappings in RBs and above. Therefore for every RB in the driver, we take a look at the POs that are connected to it in the driver, and the RB it maps to in the recipient, and its POs in the Recipient.
#
# 5.2 The mapping connection between RBs is upweighted if the indices of its POs match. Ex - RB1 maps to RB2 with weight w. PO11 and PO12 are the POs connected to RB1, and PO21 and PO22 are the POs connected to RB2. index(PO11), index(PO12), index(PO21), index(PO22) indicate where they appear in the RBs. Spearman Rank correlation between them should point to how similar they are.
#
# ## Stuff to do :
#
# 1. First, collect all mapping hypotheses in one place. This consists of all connections from Driver propositions to all recipient tokens of same type.
#
# 1.1 Don't break it now, but the Luce's choice algorithm is a bit weird. Gotta see why they use it. - instead of random threshold to retrieve analogs, use a fixed threshold = 0.1 currently
#
# 1.2 with threshold = 0.1, biasing proposition length as well, RMSE = 0.11 - looks bad. Got to find out a way to include RB firing order instead.
#
# 1.3 Make sure P in parent is mapped to P in parent only.
#
# 1.4 After taking out the one to one mapping constraint, mappings improve. - RMSE = 0.0853, set parent_bias = 0.5!
#
# 1.5 setting parent_bias = 0.1 , 0.088 (not significant enough imo)
#
# 1.6 see how firing order similarity is affecting mapping coeff. Currently, mapping is in SSL, guided by a simple Hebbian learning rule that has coactivation as its basis. added correlations between activations to update_hyp. Correlations + one_to_one == True, RMSE = 0.067, one_to_one == False, RMSE = 0.077 (higher rmse :O )
#
# 1.7 Something to test out - parent and child modes need to be updated based on presence of parentRBs, not activations alons, nah?
#
# 1.8 Run with larger prop number
#
# 1.9 Non recursive correlational mapping - 0.111
#
# ## Results -
#
# 1.1 Collect RMSE over time, and plot the evolution
# 1.2 Comparison across word embedding strategies used
# 1.3 Record RB firing for proposition 0 in Ding stimuli style
